# %% [markdown]
# # Neuroevoluce

# %% [markdown]
# Pomocí evolučních algoritmů můžeme vyvíjet i celé neuronové sítě. Buď můžeme evolvovat váhy mezi neurony, strukturu sítě nebo obojí najednou. Nejprve se podíváme, jak naimplementovat jednoduchý algoritmus pro evoluci vah, následně si zkusíme i evoluci vah a struktury sítě najednou pomocí algoritmu NEAT.

# %% [markdown]
# ## Evoluce vah
#
# Evoluce vah je jednoduchá, stačí naimplementovat jednoduchou neuronovou síť, které umíme nastavit parametry. Náš jedinec v evoluci bude jeden dlouhý vektor, který bude reprezentovat váhy mezi vrstvami v neuronové síti. Při vyhodnocování tedy nastavíme síti váhy podle daného jedince a spočítáme její výstup. Zkusíme si tímto způsobem implementovat klasifikaci na našem oblíbeném datasetu iris.

# %%
import numpy as np

import sklearn

from deap import algorithms, creator, base, cma, tools

# %% [markdown]
# Začneme tím, že si připravíme jednoduchou implementaci neuronové sítě. Při inicializaci nastavíme vrstvy, jejich velikosti a také jejich aktivace, jelikož každá vrstva může mít svou vlastní aktivační funkci.
#
# Dále budeme potřebovat jednoho dlouhého linárního jedince všech vah rozdělit na váhové matice. To uděláme tak, že budeme brát vždy velikost akutální a následující vrstvy, na základě toho vezmeme odpovídající část jedince a vytvoříme z něj matici vah. Zároveň musíme přidat biasy, takže velikost aktuální vrstvy zvětšíme ještě o 1.
#
# Nakonec bude potřeba ještě funkce pro evaluaci sítě, která vytvořenou síť vyhodnotí tak, že pro každou vrstvu použije odpovídající aktivaci a vrátí nám výstup sítě.

# %%
class NeuralNetwork:
    def __init__(self, layer_sizes, activations):
        self.layer_sizes = layer_sizes
        self.layers = None

        # Checking, whether the number of activations corresponds to the number of layers
        if len(list(activations)) != len(layer_sizes) - 1:
            raise AttributeError("Number of activations does not match number of layers")
        
        self.activations = list(activations)
        self.vectorized_net = None


    # Returns total number of parameters of the network
    def vectorized_size(self):
        return sum(map(lambda x: (x[0] + 1) * x[1], zip(self.layer_sizes, self.layer_sizes[1:])))


    # Sets weights of the network using the values given by the linear individual
    def set_weights(self, vectorized_net):
        
        # Checking, whether the sizes match
        if len(vectorized_net) != self.vectorized_size():
            raise AttributeError(
                f"Length of vector does not match vectorized_size: {len(vectorized_net)} != {self.vectorized_size()}"
            )

        self.vectorized_net = vectorized_net
        self.layers = []
        sum_sizes = 0 # Sum of sizes of the previous layers (number of already processed elements)
        
        # Go through layers and set weight matrix between the current one and the following one
        # using the corresponding values from the linear indivudual.
        for (input_layer_size, output_layer_size) in zip(self.layer_sizes, self.layer_sizes[1:]):
            number_of_corresponding_elements = (input_layer_size + 1) * output_layer_size
            
            layer = vectorized_net[sum_sizes:(sum_sizes + number_of_corresponding_elements)]
            self.layers.append(np.reshape(layer, shape=(input_layer_size + 1, output_layer_size))) # Reshaping to the correct format
            
            sum_sizes += number_of_corresponding_elements


    # Evaluation of the network
    def eval_network(self, inputs):
        activations = inputs
        
        for activation_function, layer in zip(self.activations, self.layers):
            activations_1 = np.append(np.array([1.0]), activations)  # Extending the input vector by a constant one to be multiplied by the bias part of the weights
            activations = activation_function(np.dot(activations_1, layer))

        return activations

# %% [markdown]
# Nyní si akorát načteme data a rozdělíme si je na trénovací a testovací.

# %%
iris = sklearn.datasets.load_iris()
train_x, test_x, train_y, test_y = sklearn.model_selection.train_test_split(iris.data, iris.target)

# %% [markdown]
# Musíme si ještě definovat fitness funkci, což bude pouze vyhodnocení sítě na datech, kdy vždy vybereme jako predikovanou třídu tu s maximální pravděpodobností a spočítáme pak celkovou accuracy. Zároveň si definujeme vlastní lineární a relu aktivace.

# %%
def relu(x):
    return np.maximum(0, x)

def linear(x):
    return x

def fitness(net, ind, X, y):
    net.set_weights(ind)
    
    acc = 0
    for xi, yi in zip(X, y):
        if np.argmax(net.eval_network(xi)) == yi:
            acc += 1
    
    return acc / len(y),

# %% [markdown]
# Pro samotné nastavení vah neuronové sítě použíjeme algoritmus CMA-ES, což je evoluční strategie, která je velmi dobrá na úlohy spojité optimalizace, kterou máme i zde. V evoluční strategii se většinou nevyskytuje křížení, ale místo něj se klade důraz na mutaci. Zde se používá nám známá gaussovská mutace. CMA-ES funguje tak dobře proto, že nám umožňuje váhy měnit korelovaně, protože si pamatuje celou kovariační matici, ze které generuje jedince. Klasická evoluce umí měnit váhy jen nezávisle na sobě, a dává proto horší výsledky. CMA-ES je implementována v knihovně deap, a je tedy snadné ji použít.

# %%
net = NeuralNetwork([4, 5, 3], [relu, linear])
ind_size = net.vectorized_size()    
    
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("evaluate", lambda ind, X, y: fitness(net, ind, X, y), X=train_x, y=train_y)

strategy = cma.Strategy(centroid=[0.0] * ind_size, sigma=0.1, lambda_= 5 * ind_size)
toolbox.register("generate", strategy.generate, creator.Individual)
toolbox.register("update", strategy.update)

hof = tools.HallOfFame(1)
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("avg", np.mean)
stats.register("std", np.std)
stats.register("min", np.min)
stats.register("max", np.max)

_ = algorithms.eaGenerateUpdate(toolbox, ngen=250, stats=stats, halloffame=hof)
# Out:
# gen	nevals	avg     	std     	min	max
# 0  	215   	0.344518	0.095545	0  	0.660714
# 1  	215   	0.341404	0.0986699	0  	0.669643
# 2  	215   	0.350498	0.0923738	0  	0.669643
# 3  	215   	0.345183	0.10885  	0  	0.669643
# 4  	215   	0.360548	0.0810503	0  	0.696429
# 5  	215   	0.361213	0.0815033	0.0446429	0.669643
# 6  	215   	0.352118	0.0976348	0        	0.669643
# 7  	215   	0.365075	0.0877089	0        	0.669643
# 8  	215   	0.383056	0.0898631	0.294643 	0.669643
# 9  	215   	0.385548	0.107688 	0.0178571	0.910714
# 10 	215   	0.374419	0.116607 	0        	0.6875
# 11 	215   	0.397924	0.119257 	0        	0.696429
# 12 	215   	0.408389	0.135714 	0.00892857	0.6875
# 13 	215   	0.420515	0.141308 	0.00892857	0.723214
# 14 	215   	0.405482	0.136776 	0.0178571 	0.669643
# 15 	215   	0.433804	0.141139 	0         	0.669643
# 16 	215   	0.441694	0.143677 	0.0803571 	0.669643
# 17 	215   	0.433098	0.141147 	0.0535714 	0.830357
# 18 	215   	0.420889	0.146544 	0         	0.910714
# 19 	215   	0.44157 	0.13989  	0.241071  	0.678571
215   	0.982143	2.22045e-16	0.982143  	0.982143
# 229	215   	0.98206 	0.000857133	0.973214  	0.982143
# 230	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 231	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 232	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 233	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 234	215   	0.982101	0.000607506	0.973214  	0.982143
# 235	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 236	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 237	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 238	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 239	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 240	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 241	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 242	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 243	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 244	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 245	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 246	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 247	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 248	215   	0.982143	2.22045e-16	0.982143  	0.982143
# 249	215   	0.982101	0.000607506	0.973214  	0.982143

# %% [markdown]
# Na závěr si zkusíme otestovat síť na testovacích datech a změřit na nich accuracy.

# %%
accuracy = fitness(net, hof[0], test_x, test_y)[0]
print("Achieved accuracy:", accuracy)
# Out:
# Achieved accuracy: 1.0

# %% [markdown]
# ## NEAT
#
# Zkusíme se podívat na algoritmus NEAT na příkladu s datasetem iris a zkusíme pro něj najít co nejvhodnější síť, která bude umět data pokud možno co nejlépe klasifikovat. Samotná implementace algorimtu není vůbec jednoduchá, ale naštěstí v pythonu existuje knihovna neat-python, kde už tu práci někdo udělal za nás (instalujeme pomocí `pip install neat-python`). Knihovna má trochu jiný interface, než na co jsme zvyklí, ale není složité se jí naučit používat. Nastavení parametrů algoritmu se načítá ze zvláštního souboru *config-feedforward*. Dokumentace k jeho formátování se nachází [zde](https://neat-python.readthedocs.io/en/latest/config_file.html). Potom už stačí jen algoritmus spustit. Níže uvedený příklad vychází z dokumentace k [neat-python](https://github.com/CodeReclaimers/neat-python/tree/master/examples/xor) upravený pro naši klasifikaci irisů.

# %%
import neat
import visualize

# %%
# Construction and evaluation of a network in NEAT - basically a fitness function
def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        genome.fitness = 0.0
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        
        for xi, xo in zip(train_x, train_y): 
            output = net.activate(xi)
            if np.argmax(output) == xo:
                genome.fitness += 1

# %%
# Path to the configuration file
config_path = "config-feedforward"

# Load NEAT configuration
config = neat.Config(
    neat.DefaultGenome,
    neat.DefaultReproduction,
    neat.DefaultSpeciesSet,
    neat.DefaultStagnation,
    config_path
)

# Create new population
population = neat.Population(config)

# Add statistics computation for evolution logging
population.add_reporter(neat.StdOutReporter(show_species_detail=True))
stats = neat.StatisticsReporter()
population.add_reporter(stats)

# Run for a given number of generations
winner = population.run(eval_genomes, 100)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 33.88667 stdev: 14.80204
# Best fitness: 71.00000 - size: (3, 12) - species 1 - id 22
# Average adjusted fitness: 0.477
# Mean genetic distance 1.109, standard deviation 0.262
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    0   150     71.000    0.477     0
# Total extinctions: 0
# Generation time: 0.115 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 40.63333 stdev: 11.89085
# Best fitness: 75.00000 - size: (3, 12) - species 1 - id 189
# Average adjusted fitness: 0.542
# Mean genetic distance 1.099, standard deviation 0.278
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    1   150     75.000    0.542     0
# Total extinctions: 0
# Generation time: 0.078 sec (0.096 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 40.16000 stdev: 11.60062
# Best fitness: 75.00000 - size: (3, 12) - species 1 - id 294
# Average adjusted fitness: 0.535
# Mean genetic distance 1.257, standard deviation 0.285
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    2   150     75.000    0.535     1
# Total extinctions: 0
# Generation time: 0.143 sec (0.112 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 44.40000 stdev: 14.98444
# Best fitness: 84.00000 - size: (4, 10) - species 1 - id 556
# Average adjusted fitness: 0.529
# Mean genetic distance 1.540, standard deviation 0.294
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    3   150     84.000    0.529     0
# Total extinctions: 0
# Generation time: 0.081 sec (0.104 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 46.28000 stdev: 17.40886
# Best fitness: 101.00000 - size: (3, 10) - species 1 - id 714
# Average adjusted fitness: 0.458
# Mean genetic distance 1.604, standard deviation 0.354
# Population of 150 members in 1 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    4   150    101.000    0.458     0
# Total extinctions: 0
# Generation time: 0.074 sec (0.098 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 46.77333 stdev: 16.93050
# Best fitness: 101.00000 - size: (3, 10) - species 1 - id 714
# Average adjusted fitness: 0.463
# Mean genetic distance 1.863, standard deviation 0.563
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    5   133    101.000    0.463     1
#      2    0    17         --       --     0
# Total extinctions: 0
# Generation time: 0.103 sec (0.099 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 45.78667 stdev: 17.63428
# Best fitness: 101.00000 - size: (3, 10) - species 1 - id 714
# Average adjusted fitness: 0.403
# Mean genetic distance 2.168, standard deviation 0.566
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    6   104    101.000    0.454     2
#      2    1    46     63.000    0.353     0
# Total extinctions: 0
# Generation time: 0.144 sec (0.106 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 47.73333 stdev: 18.31672
# Best fitness: 106.00000 - size: (3, 6) - species 1 - id 1151
# Average adjusted fitness: 0.442
# Mean genetic distance 2.271, standard deviation 0.587
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    7   113    106.000    0.464     0
#      2    2    37     75.000    0.419     0
# Total extinctions: 0
# Generation time: 0.142 sec (0.110 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 47.92000 stdev: 18.22654
# Best fitness: 106.00000 - size: (3, 6) - species 1 - id 1151
# Average adjusted fitness: 0.440
# Mean genetic distance 2.130, standard deviation 0.511
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    8    66    106.000    0.464     1
#      2    3    84     75.000    0.415     1
# Total extinctions: 0
# Generation time: 0.072 sec (0.106 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 47.81333 stdev: 16.40625
# Best fitness: 106.00000 - size: (3, 6) - species 1 - id 1151
# Average adjusted fitness: 0.315
# Mean genetic distance 2.055, standard deviation 0.437
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    9    67    106.000    0.311     2
#      2    4    83    101.000    0.319     0
# Total extinctions: 0
# Generation time: 0.074 sec (0.103 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 45.93333 stdev: 15.91589
# Best fitness: 106.00000 - size: (3, 6) - species 1 - id 1151
# Average adjusted fitness: 0.402
# Mean genetic distance 2.118, standard deviation 0.466
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   10    84    106.000    0.426     3
#      2    5    66    101.000    0.378     1
# Total extinctions: 0
# Generation time: 0.094 sec (0.101 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 50.36667 stdev: 18.80086
# Best fitness: 106.00000 - size: (3, 6) - species 1 - id 1151
# Average adjusted fitness: 0.470
# Mean genetic distance 2.169, standard deviation 0.475
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   11    73    106.000    0.471     4
#      2    6    77    101.000    0.469     2
# Total extinctions: 0
# Generation time: 0.094 sec (0.102 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 52.46000 stdev: 17.88803
# Best fitness: 106.00000 - size: (3, 6) - species 2 - id 1151
# Average adjusted fitness: 0.491
# Mean genetic distance 2.126, standard deviation 0.498
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   12    62     75.000    0.515     5
#      2    7    88    106.000    0.466     0
# Total extinctions: 0
# Generation time: 0.074 sec (0.095 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 51.69333 stdev: 17.49474
# Best fitness: 106.00000 - size: (3, 6) - species 2 - id 1151
# Average adjusted fitness: 0.463
# Mean genetic distance 2.180, standard deviation 0.437
# Population of 150 members in 2 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   13    72     77.000    0.500     6
#      2    8    78    106.000    0.427     1
# Total extinctions: 0
# Generation time: 0.074 sec (0.095 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 50.54667 stdev: 19.01739
# Best fitness: 106.00000 - size: (3, 6) - species 2 - id 1151
# Average adjusted fitness: 0.430
# Mean genetic distance 2.345, standard deviation 0.482
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   14    59     84.000    0.479     7
#      2    9    50    106.000    0.382     2
#      3    0    41         --       --     0
# Total extinctions: 0
# Generation time: 0.150 sec (0.102 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 52.73333 stdev: 18.08191
# Best fitness: 106.00000 - size: (3, 6) - species 2 - id 1151
# Average adjusted fitness: 0.263
# Mean genetic distance 2.317, standard deviation 0.565
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   15    60     84.000    0.256     8
#      2   10    36    106.000    0.224     3
#      3    1    54     83.000    0.311     0
# Total extinctions: 0
# Generation time: 0.080 sec (0.100 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 56.32000 stdev: 18.63592
# Best fitness: 106.00000 - size: (3, 6) - species 2 - id 1151
# Average adjusted fitness: 0.306
# Mean genetic distance 2.219, standard deviation 0.557
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   16    70     84.000    0.355     9
#      2   11    39    106.000    0.292     4
#      3    2    41     82.000    0.272     1
# Total extinctions: 0
# Generation time: 0.072 sec (0.093 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 54.32667 stdev: 19.86605
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.464
# Mean genetic distance 2.263, standard deviation 0.498
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   17    61    107.000    0.484     0
#      2   12    29    106.000    0.473     5
#      3    3    60     82.000    0.436     2
# Total extinctions: 0
# Generation time: 0.080 sec (0.086 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 52.08000 stdev: 18.75616
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.473
# Mean genetic distance 2.232, standard deviation 0.517
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   18    58    107.000    0.494     1
#      2   13    35     75.000    0.409     6
#      3    4    57    106.000    0.517     0
# Total extinctions: 0
# Generation time: 0.145 sec (0.094 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 51.70667 stdev: 18.76328
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.327
# Mean genetic distance 2.223, standard deviation 0.459
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   19    38    107.000    0.336     2
#      2   14    59     75.000    0.282     7
#      3    5    53    106.000    0.363     1
# Total extinctions: 0
# Generation time: 0.146 sec (0.101 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 57.26667 stdev: 18.85972
# Best fitness: 107.00000 - size: (4, 6) - species 2 - id 2621
# Average adjusted fitness: 0.491
# Mean genetic distance 2.164, standard deviation 0.444
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   20    29     96.000    0.506     3
#      2   15    72    107.000    0.431     0
#      3    6    49    106.000    0.537     2
# Total extinctions: 0
# Generation time: 0.113 sec (0.103 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 53.70000 stdev: 19.61250
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.272
# Mean genetic distance 1.987, standard deviation 0.479
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   21    48    107.000    0.283     4
#      2   16    50    106.000    0.266     1
#      3    7    52     84.000    0.268     3
# Total extinctions: 0
# Generation time: 0.136 sec (0.107 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 56.31333 stdev: 19.86761
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.382
# Mean genetic distance 1.970, standard deviation 0.486
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   22    66    107.000    0.366     5
#      2   17    38    106.000    0.385     2
#      3    8    46     84.000    0.394     4
# Total extinctions: 0
# Generation time: 0.116 sec (0.111 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 53.04667 stdev: 19.83745
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.437
# Mean genetic distance 2.000, standard deviation 0.489
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   23    58    107.000    0.505     6
#      2   18    33    106.000    0.371     3
#      3    9    59     84.000    0.435     5
# Total extinctions: 0
# Generation time: 0.074 sec (0.111 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 57.39333 stdev: 19.09481
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.453
# Mean genetic distance 1.944, standard deviation 0.503
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   24    65    107.000    0.514     7
#      2   19    45    106.000    0.407     4
#      3   10    40     84.000    0.438     6
# Total extinctions: 0
# Generation time: 0.073 sec (0.103 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 55.10667 stdev: 20.04134
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.465
# Mean genetic distance 1.930, standard deviation 0.531
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   25    60    107.000    0.465     8
#      2   20    39    106.000    0.457     5
#      3   11    51     84.000    0.474     7
# Total extinctions: 0
# Generation time: 0.081 sec (0.104 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 56.92667 stdev: 19.00530
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.313
# Mean genetic distance 1.903, standard deviation 0.543
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   26    45    107.000    0.324     9
#      2   21    52    106.000    0.303     6
#      3   12    53     84.000    0.310     8
# Total extinctions: 0
# Generation time: 0.139 sec (0.110 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 56.86667 stdev: 20.06345
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.509
# Mean genetic distance 1.902, standard deviation 0.557
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   27    55    107.000    0.522    10
#      2   22    41    106.000    0.471     7
#      3   13    54     84.000    0.533     9
# Total extinctions: 0
# Generation time: 0.127 sec (0.115 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 57.82667 stdev: 19.66070
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.325
# Mean genetic distance 1.937, standard deviation 0.597
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   28    45    107.000    0.339    11
#      2   23    52    106.000    0.314     8
#      3   14    53     84.000    0.322    10
# Total extinctions: 0
# Generation time: 0.072 sec (0.108 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 57.26000 stdev: 19.47149
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.319
# Mean genetic distance 1.876, standard deviation 0.597
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   29    47    107.000    0.329    12
#      2   24    47    106.000    0.284     9
#      3   15    56     84.000    0.343    11
# Total extinctions: 0
# Generation time: 0.080 sec (0.101 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 56.39333 stdev: 19.25302
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.325
# Mean genetic distance 1.942, standard deviation 0.581
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   30    49    107.000    0.336    13
#      2   25    42    106.000    0.309    10
#      3   16    59     84.000    0.330    12
# Total extinctions: 0
# Generation time: 0.140 sec (0.104 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 54.80000 stdev: 19.71057
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.282
# Mean genetic distance 1.985, standard deviation 0.599
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   31    57    107.000    0.306    14
#      2   26    40     75.000    0.246    11
#      3   17    53     91.000    0.295    13
# Total extinctions: 0
# Generation time: 0.119 sec (0.102 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 57.12000 stdev: 19.08435
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.509
# Mean genetic distance 1.931, standard deviation 0.583
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   32    50    107.000    0.503    15
#      2   27    50     76.000    0.487    12
#      3   18    50     91.000    0.538    14
# Total extinctions: 0
# Generation time: 0.071 sec (0.098 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 56.88000 stdev: 18.71859
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.430
# Mean genetic distance 1.909, standard deviation 0.565
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   33    64    107.000    0.400    16
#      2   28    38     76.000    0.427    13
#      3   19    48     91.000    0.464    15
# Total extinctions: 0
# Generation time: 0.090 sec (0.099 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 54.10000 stdev: 18.11914
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.282
# Mean genetic distance 1.924, standard deviation 0.508
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   34    40    107.000    0.229    17
#      2   29    64     76.000    0.291    14
#      3   20    46     91.000    0.325    16
# Total extinctions: 0
# Generation time: 0.142 sec (0.106 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 56.68000 stdev: 19.39083
# Best fitness: 107.00000 - size: (4, 6) - species 1 - id 2621
# Average adjusted fitness: 0.351
# Mean genetic distance 1.917, standard deviation 0.551
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   35    40    107.000    0.375    18
#      2   30    62     89.000    0.319    15
#      3   21    48     91.000    0.360    17
# Total extinctions: 0
# Generation time: 0.082 sec (0.106 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 57.56000 stdev: 20.06306
# Best fitness: 109.00000 - size: (4, 5) - species 2 - id 5336
# Average adjusted fitness: 0.314
# Mean genetic distance 1.999, standard deviation 0.561
# Population of 150 members in 3 species (after reproduction):
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   36    44    107.000    0.263    19
#      2   31    58    109.000    0.282     0
#      3   22    48    102.000    0.398    18
# Total extinctions: 0
# Generation time: 0.072 sec (0.099 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 59.44667 stdev: 21.18035
# Best fitness: 110.00000 - size: (4, 5) - species 2 - id 5497
#
# Best individual in generation 37 meets fitness threshold - complexity: (4, 5)

# %%
# Show the best individual and its accuracy on test data
print(f"*Best genome*\n{winner}")

winner_net = neat.nn.FeedForwardNetwork.create(winner, config)
num_of_correct_predictions = 0
for input_example, correct_output in zip(test_x, test_y):
    output = winner_net.activate(input_example)
    prediction = np.argmax(output)
        
    if prediction == correct_output:
        num_of_correct_predictions += 1
    
print("\nTotal accuracy on the test data:", num_of_correct_predictions / len(test_y))

# Render the best network
node_names = {-1:"x1", -2: "x2", -3: "x3", -4: "x4", 0:"setosa", 1:"virginica", 2:"versicolor"}
visualize.draw_net(
    config,
    genome=winner,
    node_names=node_names,
    show_disabled=True,
    prune_unused=False
)

# Plot the statistics
visualize.plot_stats(stats, ylog=False, view=True)
visualize.plot_species(stats, view=True)
# Out:
# *Best genome*
# Key: 5497
# Fitness: 110.0
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=3.847266640460285, response=1.0, activation=sigmoid, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=2.1345653890821548, response=1.0, activation=sigmoid, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=1.2273687660577406, response=1.0, activation=sigmoid, aggregation=sum)
# 	416 DefaultNodeGene(key=416, bias=0.32223894700504646, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-4, 0), innovation=10, weight=-0.1954965142029843, enabled=False)
# 	DefaultConnectionGene(key=(-4, 1), innovation=11, weight=-1.7205869118886319, enabled=False)
# 	DefaultConnectionGene(key=(-4, 2), innovation=2557, weight=0.9442083856528259, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), innovation=7, weight=-3.0947415937616625, enabled=True)
# 	DefaultConnectionGene(key=(-3, 2), innovation=9, weight=-0.5869155176781349, enabled=False)
# 	DefaultConnectionGene(key=(-2, 0), innovation=4, weight=0.7217231435438273, enabled=False)
# 	DefaultConnectionGene(key=(-2, 1), innovation=5, weight=3.1817901897033076, enabled=False)
# 	DefaultConnectionGene(key=(-1, 0), innovation=1, weight=1.358006206938895, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1), innovation=2, weight=-0.14197990361018092, enabled=False)
# 	DefaultConnectionGene(key=(-1, 2), innovation=3, weight=-1.4973326586711226, enabled=False)
# 	DefaultConnectionGene(key=(416, 0), innovation=2765, weight=-0.3288600308128049, enabled=True)
# 	DefaultConnectionGene(key=(416, 2), innovation=1038, weight=-0.8956741776347708, enabled=True)
#
# Total accuracy on the test data: 0.8947368421052632

# %% [markdown]
# ## Domácí úkol - Zpětnovazební učení s využitím neuroevoluce
#
# Za domácí úkol budete mít vyzkoušet si vyřešit některá prostředí z knihovny [Gymnasium](https://gymnasium.farama.org/). Vyzkoušet můžete buď NEAT (v takovém případě můžete použít třeba knihovnu, kterou jsme si právě vyzkoušeli, jen nezapomeňte přizpůsobit konfigurační soubor, fitness a tak podobně), vyvíjet jen vektor vah fixní sítě, nebo cokoli vás napadne.
#
# [Detailní zadání](https://kam.mff.cuni.cz/~lorenc/teach/PIA_hw/homeworks-neuroevolution.html) je možno najít na stránkách cvičení.
