# %% [markdown]
# # Neuronové sítě

# %% [markdown]
# Na přednášce jste slyšeli úvod do další přírodou inspirované techniky - neuronových sítí. Mezi jejich nejjednodušší modely patří perceptron a vícevrstevný perceptron. Na cvičení si je tedy zkusíme sami naimplementovat.

# %% [markdown]
# ***Důležitá poznámka:*** Níže importujeme *sklearn*. Budete-li pipem instalovat [*"sklearn"*](https://pypi.org/project/sklearn/), dost možná se vám to v nějaké formě povede nainstalovat, pravé jméno projektu / package je ale [*"scikit-learn"*](https://pypi.org/project/scikit-learn/), a tedy by měl být instalován následovně: `pip install scikit-learn`. *sklearn* je pouze jméno pro import. Je to matoucí? Jo. Ale já to nevymyslel...

# %%
import collections
import os

# Library tqdm is a useful tool for creating progress bars
from tqdm import trange

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import pylab as pl

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn import preprocessing
from sklearn.utils import shuffle

# Turns off GPU computation of Tensorflow, when that functionality is installed
# (We are using really small networks, hence the communication overhead
# is much more significant, than the computational boost we gain by utilizing
# the power of the GPU.)
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import tensorflow as tf

# %% [markdown]
# ## Perceptron

# %% [markdown]
# Nejprve si tedy zkusíme naimplementovat jednoduchý perceptronový algoritmus učení. K tomu budeme potřebovat třídu *Perceptron*, kde si definujeme, jak jednoduchý perceptron vypadá. Při inicializaci se nastaví maximální počet iterací a learning rate, který určuje rychlost učení algoritmu, a přípraví se vektor vah a bias.
#
# Funkce *predict* nám pro daný vstup bude predikovat jeho výstup - a to tak, že se spočítá hodnota aktivační funkce ve vstupním bodě a pokud bude větší než 0, bude aktivace 1, jinak bude aktivace 0.
#
# Budeme ještě potřebovat funkci *fit*, kde se budou trénovat váhy perceptronu tak, že pro daný vstup spočteme jeho predikovaný výstup a pokud je špatný, tak upravíme váhy tak, aby příště predikoval výstup správně.

# %%
class Perceptron:
    def __init__(self, number_of_inputs, training_iterations, learning_rate=0.1):
        self.weights = np.random.normal(size=number_of_inputs)
        self.bias = np.random.normal()
        
        self.training_iterations = training_iterations
        self.learning_rate = learning_rate
        
        
    def predict(self, inputs):
        # Compute an output of the function for the given inputs, weights and bias
        intermediate_value = np.dot(inputs, self.weights) + self.bias
        # Calculate activation
        return (np.sign(intermediate_value) + 1) / 2
    
    
    def fit(self, inputs, labels):
        for _ in range(self.training_iterations):
            for x, y in zip(inputs, labels):
                prediction = self.predict(x)               
                
                # Learning
                self.weights += self.learning_rate * (y - prediction) * x
                self.bias += self.learning_rate * (y - prediction)

# %% [markdown]
# Abychom náš perceptron otestovali, vygenerujeme si náhodná data pomocí knihovny *scikit-learn*, která nám umí vrátit 2 (občas i) lineárně separabilní třídy bodů.

# %%
inputs, labels = datasets.make_blobs(centers=2, n_samples=200)

# %%
perc = Perceptron(2, 100)
perc.fit(inputs, labels)

# %% [markdown]
# Ještě by bylo fajn umět si vizualizovat výsledky - proto si napíšeme následující funkci, která bude umět vykreslit data i oddělující nadrovinu.

# %%
def draw_boundary(model, inputs, labels):
    x_min = inputs[:, 0].min() - 1
    x_max = inputs[:, 0].max() + 1
    y_min = inputs[:, 1].min() - 1 
    y_max = inputs[:, 1].max() + 1

    # Create rectangular grid with the above computed dimensions
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    
    # Drawing of the decision boundary - each point gets a color accordingly
    predicted = model.predict(np.c_[xx.ravel(), yy.ravel()])
    predicted = predicted.reshape(xx.shape)
    
    plt.figure(figsize=(12,8))
    plt.scatter(inputs[:,0], inputs[:,1], c=labels)
    plt.contourf(xx, yy, predicted, alpha=0.4)
    plt.show()

# %%
draw_boundary(perc, inputs, labels)

# %% [markdown]
# ## Vícevrstvý perceptron

# %% [markdown]
# Jednoduchý perceptron už umíme, tak si nyní s jeho pomocí zkusíme napsat vícevrstvý perceptron, neboli celou (plně propojenou) neuronovou síť. V inicializační části nastavíme velikosti vrstev a poté matice vah mezi jednotlivými vrstvami jakožto náhodné hodnoty. Dále bude třeba umět predikovat výstupní hodnotu sítě pro daný vstup. Nakonec bude potřeba funkce trénování, která pro daný vstup spočítá výstup sítě a následně updatuje váhy pomocí backpropagace.

# %%
def sigmoid(x):
    # Clip the values to prevent overflows
    x = x.clip(-5e2,5e2)
    
    return 1 / (1 + np.exp(-x))


class MultiLayerPerceptron:
    def __init__(self, layer_sizes, training_iterations=1, learning_rate=0.01):
        self.layer_sizes = layer_sizes
        self.weights = []
        self.training_iterations = training_iterations
        self.learning_rate = learning_rate
        self.last_run_activations = None # For gradient computation
        
        for (input_layer_size, output_layer_size) in zip(self.layer_sizes, self.layer_sizes[1:]):
           self.weights.append(np.random.normal(size=(input_layer_size + 1, output_layer_size)))
           
           
    def _add_ones(self, x):
        """ Add a column of ones for bias (the first row in the weight matrix represents the biases) """
        ones = np.ones(shape=(x.shape[0], 1))
        return np.concatenate([ones, x], axis=1)
    
    
    def predict(self, inputs):
        activations = np.array(inputs)
        self.last_run_activations = [activations]
        
        try:
            for layer in self.weights:
                extended_activations = self._add_ones(activations)
                linear_combination = np.dot(extended_activations, layer)
                activations = sigmoid(linear_combination)
                self.last_run_activations.append(activations)
                
        except Exception as e:
            print("Activations:", activations)
            raise e

        return activations
    
    
    def fit(self, inputs, labels):
        progress_bar = trange(self.training_iterations)
        for i in progress_bar:
            # Compute the NN's output
            self.predict(inputs)
            
            # Perform the backpropagation
            self._perform_backpropagation(labels)
            
            # Check the performance once per hundered iterations
            if i % 100 == 0:
                predictions = self.predict(inputs)
                predicted_classes = np.argmax(predictions, axis=-1)
                model_accuracy = accuracy_score(predicted_classes, labels)
                progress_bar.set_description(f"Accuracy after iteration {i}: {model_accuracy}")
        
        
    def _perform_backpropagation(self, labels):
        # We assume a square error loss function, so L = 1/2 * sum((predictions - one_hot_targets)^2)
        one_hot_labels = np.zeros_like(self.last_run_activations[-1])
        one_hot_labels[np.arange(len(one_hot_labels)), labels] = 1
        
        # Try to implement the backpropagation yourself. - It's not easy. To be honest, it could be rather hard and maybe tricky.
        # It is not necessary to do this, so feel free to skip this one, but you can take it as a challange and check your understanding
        # of the backpropagation algorithm and of the mathematical analysis.
        # If you are willing to try, you can do so by following the ensuing steps, or do it in any other way you like.
    
        # Compute the gradients of the loss with respect to inputs of all the layers (except the first one)
        pass
    
        # Compute the gradients of the loss with respect to the model's parameters for all the layers and update the parameters
        pass

# %%
mlp = MultiLayerPerceptron([3,5,2])
# Predicting in batch
mlp.predict(np.array([[1,2,3], [1,2,7]]))
# Out:
# array([[0.19761249, 0.77523565],
#        [0.1972904 , 0.74515686]])

# %% [markdown]
# ## Úkol na cvičení
#
# Zkuste si dopsat funkci `fit`, resp. `_perform_backpropagation` u vícevrstevného perceptronu a natrénovat ho na obdobě náhodných dat výše s více výstupními kategoriemi.
#
# (Použijte MSE jako loss funkci, resp. její variantu bez průměrování, jen s dělením součtu čtverců dvěma, tedy $\frac{1}{2} \sum(\texttt{predictions} - \texttt{one\_hot\_targets})^2$. Jednoduše se derivuje a pro naše účely dostatečně dobře funguje. Dále derivace sigmoid funkce je následovná: $(\sigma(x))' = \sigma(x) \cdot (1 - \sigma(x))$ )

# %% [markdown]
# Nejprve si vytvoříme náhodná dvojrozměrná data klasifikovatelná do n tříd, abychom si je mohli i hezky vizualizovat v grafu. K tomu bude potřeba si upravit funkci pro vizualizaci, protože vícetřídová klasifikace nám vrací výstup jakožto pole, kde pro danou jednu vybranou třídu (ideálně) bude na jejím indexu 1 a všude jinde budou 0. Tomuto výstupu se tak říká one-hot-encoding.

# %%
def draw_boundary_multiclass(model, inputs, labels):
    x_min = inputs[:, 0].min() - 1
    x_max = inputs[:, 0].max() + 1
    y_min = inputs[:, 1].min() - 1 
    y_max = inputs[:, 1].max() + 1

    # Create rectangular grid with the above computed dimensions
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    
    # Drawing of the decision boundary - each point gets a color accordingly
    predicted = model.predict(np.c_[xx.ravel(), yy.ravel()])
    
    # Extracting the predicted class number from the one-hot-encoding
    predicted = np.argmax(predicted, axis=1)
    
    predicted = predicted.reshape(xx.shape)
    
    plt.figure(figsize=(12,8))
    plt.scatter(inputs[:,0], inputs[:,1], c=labels)
    plt.contourf(xx, yy, predicted, alpha=0.4)
    plt.show()

# %% [markdown]
# Když máme upravenou funkci pro vizualizaci, vygenerujeme si náhodná data, vytvoříme model a podíváme se, jak byl model úspěšný, tedy jak dobře se natrénoval na trénovacích datech a jak umí predikovat data testovací.

# %%
# First let us prepare the data and split them to train and test sets
num_of_classes = 3
x, y = datasets.make_blobs(n_samples=300, centers=num_of_classes)

x_train, x_test = x[:250], x[250:]
y_train, y_test = y[:250], y[250:]

# %%
mlp = MultiLayerPerceptron([x_train.shape[1], 5, num_of_classes], training_iterations=1_000)
mlp.fit(x_train, y_train)

test_predictions = mlp.predict(x_test)
predicted_classes = np.argmax(test_predictions, axis=-1)
model_accuracy = accuracy_score(predicted_classes, y_test)
print("Accuracy on test data:", model_accuracy)
# Out:
# Accuracy after iteration 900: 0.34: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 28954.39it/s]
# Accuracy on test data: 0.3

# %%
# We make and plot predictions on the test data
draw_boundary_multiclass(mlp, x_test, y_test)

# %% [markdown]
# ## Knihovny tensorflow, keras, scikit-learn
#
# Nejprve se seznámíme s pár základními knihovnami, které budeme používat pro snažší vytváření neuronových sítí a práci s nimi. Knihovna tensorflow je symbolická matematická knihovna, která slouží pro dataflow, tedy obsahuje grafové moduly a operace, nad kterými se následně dají implementovat různé algoritmy strojového učení. Nad ní běží knihovna keras, která je navržena pro snadné experimentování s hlubokými neuronovými sítěmi. Knihovna scikit-learn zase obsahuje všechny možné běžné algoritmy strojového učení.
#
# Všechny tyto knihovny byly navrženy, aby uživateli zjednodušily práci se zpracováním dat a následné vytváření predikčních a jiných modelů, ať už pomocí neurovnových sítí nebo jiných algoritmů strojového učení.
#
# Zkusíme si tedy s pomocí těchto knihoven naimplementovat tu samou jednoduchou neuronovou sít, jakou jsme si ručně napsali výše. Budeme si potřebovat  definovat síť, natrénovat ji na trénovacích datech a nakonec ji nechat predikovat na testovacích datech.

# %%
# Define the network architecture
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, activation=tf.nn.sigmoid)) # Inner layer with 5 neurons
model.add(tf.keras.layers.Dense(num_of_classes, activation=tf.nn.softmax)) # Output layer

# Set the optimization process hyperparameters
model.compile(optimizer="sgd", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
# Train the model on the training data
model.fit(x_train, y_train, epochs=200, verbose=1)
pass
# Out:
# Epoch 1/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3120 - loss: 1.1387
# Epoch 2/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1800 - loss: 1.0846
# Epoch 3/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0840 - loss: 1.0389
# Epoch 4/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0560 - loss: 0.9999
# Epoch 5/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1000 - loss: 0.9664
# Epoch 6/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1800 - loss: 0.9370
# Epoch 7/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.2360 - loss: 0.9106
# Epoch 8/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3560 - loss: 0.8877
# Epoch 9/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4440 - loss: 0.8675
# Epoch 10/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - accuracy: 0.5280 - loss: 0.8490
# Epoch 11/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5680 - loss: 0.8326
# Epoch 12/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5880 - loss: 0.8179
# Epoch 13/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6120 - loss: 0.8046
# Epoch 14/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6240 - loss: 0.7922
# Epoch 15/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6440 - loss: 0.7812
# Epoch 16/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6480 - loss: 0.7709
# Epoch 17/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6520 - loss: 0.7613
# Epoch 18/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6520 - loss: 0.7522
# Epoch 19/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6600 - loss: 0.7440
# Epoch 20/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6600 - loss: 0.7362
# Epoch 21/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6600 - loss: 0.7288
# Epoch 22/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6600 - loss: 0.7218
# Epoch 23/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6600 - loss: 0.7153
# Epoch 24/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6640 - loss: 0.7089
# Epoch 25/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6680 - loss: 0.7029
# Epoch 26/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6680 - loss: 0.6970
# Epoch 27/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6800 - loss: 0.6914
# Epoch 28/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6800 - loss: 0.6861
# Epoch 29/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6960 - loss: 0.6807
# Epoch 30/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7120 - loss: 0.6755
# Epoch 31/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7200 - loss: 0.6705
# Epoch 32/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7480 - loss: 0.6656
# Epoch 33/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7640 - loss: 0.6608
# Epoch 34/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7800 - loss: 0.6560
# Epoch 35/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8320 - loss: 0.6512
# Epoch 36/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8480 - loss: 0.6466
# Epoch 37/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8680 - loss: 0.6418
# Epoch 38/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8920 - loss: 0.6372
# Epoch 39/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9160 - loss: 0.6325
# Epoch 40/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9480 - loss: 0.6278
# Epoch 41/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.6231
# Epoch 42/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9760 - loss: 0.6181
# Epoch 43/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9880 - loss: 0.6133
# Epoch 44/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9920 - loss: 0.6083
# Epoch 45/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.6033
# Epoch 46/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5981
# Epoch 47/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5930
# Epoch 48/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5876
# Epoch 49/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5823
# Epoch 50/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5770
# Epoch 51/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5715
# Epoch 52/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5660
# Epoch 53/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5605
# Epoch 54/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5550
# Epoch 55/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5496
# Epoch 56/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5442
# Epoch 57/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5387
# Epoch 58/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5334
# Epoch 59/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5281
# Epoch 60/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5229
# Epoch 61/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5178
# Epoch 62/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5126
# Epoch 63/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5076
# Epoch 64/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.5027
# Epoch 65/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4978
# Epoch 66/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4930
# Epoch 67/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4883
# Epoch 68/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4837
# Epoch 69/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4791
# Epoch 70/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4747
# Epoch 71/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4702
# Epoch 72/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4658
# Epoch 73/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4615
# Epoch 74/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4573
# Epoch 75/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4531
# Epoch 76/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4491
# Epoch 77/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4451
# Epoch 78/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4411
# Epoch 79/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4372
# Epoch 80/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4333
# Epoch 81/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4295
# Epoch 82/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4258
# Epoch 83/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4221
# Epoch 84/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4184
# Epoch 85/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4149
# Epoch 86/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4114
# Epoch 87/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4079
# Epoch 88/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4045
# Epoch 89/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4011
# Epoch 90/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3978
# Epoch 91/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3945
# Epoch 92/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3913
# Epoch 93/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3881
# Epoch 94/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3850
# Epoch 95/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3819
# Epoch 96/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3789
# Epoch 97/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3759
# Epoch 98/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3729
# Epoch 99/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3700
# Epoch 100/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3671
# Epoch 101/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3642
# Epoch 102/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3614
# Epoch 103/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3587
# Epoch 104/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3559
# Epoch 105/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3533
# Epoch 106/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3506
# Epoch 107/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3480
# Epoch 108/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3454
# Epoch 109/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3428
# Epoch 110/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3403
# Epoch 111/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3378
# Epoch 112/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3354
# Epoch 113/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3330
# Epoch 114/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3306
# Epoch 115/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3282
# Epoch 116/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3259
# Epoch 117/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3236
# Epoch 118/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3214
# Epoch 119/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3191
# Epoch 120/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3168
# Epoch 121/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3147
# Epoch 122/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3126
# Epoch 123/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3104
# Epoch 124/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3083
# Epoch 125/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3062
# Epoch 126/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3042
# Epoch 127/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3021
# Epoch 128/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3001
# Epoch 129/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2982
# Epoch 130/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2962
# Epoch 131/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2942
# Epoch 132/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2924
# Epoch 133/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2904
# Epoch 134/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2886
# Epoch 135/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2867
# Epoch 136/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2849
# Epoch 137/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2831
# Epoch 138/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2813
# Epoch 139/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2795
# Epoch 140/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2778
# Epoch 141/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2761
# Epoch 142/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2743
# Epoch 143/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2726
# Epoch 144/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2710
# Epoch 145/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2693
# Epoch 146/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2677
# Epoch 147/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2661
# Epoch 148/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2645
# Epoch 149/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2629
# Epoch 150/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2614
# Epoch 151/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2598
# Epoch 152/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2583
# Epoch 153/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2568
# Epoch 154/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2553
# Epoch 155/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2538
# Epoch 156/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2523
# Epoch 157/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2509
# Epoch 158/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2495
# Epoch 159/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2480
# Epoch 160/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2466
# Epoch 161/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2452
# Epoch 162/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2439
# Epoch 163/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2425
# Epoch 164/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2411
# Epoch 165/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2398
# Epoch 166/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2385
# Epoch 167/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2372
# Epoch 168/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2359
# Epoch 169/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2346
# Epoch 170/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2333
# Epoch 171/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2321
# Epoch 172/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2308
# Epoch 173/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2296
# Epoch 174/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2283
# Epoch 175/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2271
# Epoch 176/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2259
# Epoch 177/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2247
# Epoch 178/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2236
# Epoch 179/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2224
# Epoch 180/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2212
# Epoch 181/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2201
# Epoch 182/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2189
# Epoch 183/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2178
# Epoch 184/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2167
# Epoch 185/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2156
# Epoch 186/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2145
# Epoch 187/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2134
# Epoch 188/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2124
# Epoch 189/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2113
# Epoch 190/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2102
# Epoch 191/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2092
# Epoch 192/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2082
# Epoch 193/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2072
# Epoch 194/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2062
# Epoch 195/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2051
# Epoch 196/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2041
# Epoch 197/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2031
# Epoch 198/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2021
# Epoch 199/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2012
# Epoch 200/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2002

# %%
# We make and plot predictions on the test data
draw_boundary_multiclass(model, x_test, y_test)
# Out:
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step

# %% [markdown]
# Ještě si zkusíme pustit neuronovou síť z tensorflow na nějakém reálném datasetu. Použijeme dataset *winequality-white.csv* z UCI machine learning repository. Cílem u tohoto datasetu je predikovat kvalitu vína na základě 11 změřených fyzikálních a chemických vlastností. Kvalita se hodnotí na stupnici 0-10. Pojďme si nejdříve tento dataset představit a upravit.

# %%
data = pd.read_csv("winequality-white.csv", delimiter=';')
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
counter = collections.Counter(data["quality"])
print(counter)
# Out:
# Counter({6: 2198, 5: 1457, 7: 880, 8: 175, 4: 163, 3: 20, 9: 5})

# %% [markdown]
# Když se ale reálně podíváme na rozložení výsledných hodnot kvality vín v datasetu, tak vidíme, že většina výstupů je mezi 5 a 7. Proto si zjednoduššíme práci a dataset si upravíme tak, aby predikoval jen 3 výstupní kategorie s hodnotami 5 až 7 tak, že 3 a 4 sloučíme s 5 a zároveň 9 a 8 sloučíme se 7.

# %%
data["quality"] = data["quality"].replace({3: 5, 4: 5, 8: 7, 9: 7})
counter = collections.Counter(data["quality"])
print(counter)
# Out:
# Counter({6: 2198, 5: 1640, 7: 1060})

# %% [markdown]
# Nakonec, protože klasifikace se většinou provádí do tříd *0* až *K-1*, a většina algoritmů strojového učení (včetně našich sítí) je na toto uzpůsobena, posuneme i naše labely z množiny *{5, 6, 7}* do množiny *{0, 1, 2}*.

# %%
data["quality"] = data["quality"].replace({5: 0, 6: 1, 7: 2})

# %% [markdown]
# Máme tedy již upravené výstupy. Pojďme se teď podívat na vstupy a připravme si data již finálně pro naši síť.
#
# Provedeme přeškálování hodnot v datasetu tak, že všechny sloupečky budou mít hodnoty v intervalu \[0, 1\]. Škálování se dělá proto, aby se nestalo, že některý sloupeček s hodně vysokými hodnotami bude mít příliš velký vliv na výsledný predikovaný label.

# %%
# Randomly shuffle the data
data = shuffle(data)

# Get the labels
labels = data["quality"].values

# Data normalization
values = data.drop(columns="quality").values
min_max_scaler = preprocessing.MinMaxScaler()
data_scaled = min_max_scaler.fit_transform(values)

# Split the data to train and test sets
x, y = data_scaled, labels
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %% [markdown]
# Nakonec už nám nezbývá nic jiného, než si definovat naši síť a natrénovat ji.

# %%
# Define the network architecture
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, activation=tf.nn.sigmoid))
model.add(tf.keras.layers.Dense(3, activation=tf.nn.softmax))

# Set the optimization process hyperparameters
model.compile(optimizer="sgd", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Train the model on the training data
model.fit(x_train, y_train, epochs=200, verbose=1)
pass
# Out:
# Epoch 1/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.3735 - loss: 1.0912
# Epoch 2/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - accuracy: 0.4552 - loss: 1.0597
# Epoch 3/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - accuracy: 0.4549 - loss: 1.0541
# Epoch 4/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - accuracy: 0.4549 - loss: 1.0528
# Epoch 5/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - accuracy: 0.4549 - loss: 1.0521
# Epoch 6/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.4549 - loss: 1.0515
# Epoch 7/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.4549 - loss: 1.0510
# Epoch 8/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.4549 - loss: 1.0506
# Epoch 9/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.4549 - loss: 1.0501
# Epoch 10/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - accuracy: 0.4549 - loss: 1.0496
# Epoch 11/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - accuracy: 0.4549 - loss: 1.0492
# Epoch 12/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.4549 - loss: 1.0487
# Epoch 13/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - accuracy: 0.4549 - loss: 1.0482
# Epoch 14/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.4549 - loss: 1.0477
# Epoch 15/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.4549 - loss: 1.0472
# Epoch 16/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.4549 - loss: 1.0467
# Epoch 17/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - accuracy: 0.4549 - loss: 1.0463
# Epoch 18/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - accuracy: 0.4549 - loss: 1.0458
# Epoch 19/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step - accuracy: 0.4549 - loss: 1.0453
# Epoch 20/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - accuracy: 0.4549 - loss: 1.0448
# Epoch 21/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - accuracy: 0.4549 - loss: 1.0443
# Epoch 22/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - accuracy: 0.4552 - loss: 1.0438
# Epoch 23/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.4549 - loss: 1.0433
# Epoch 24/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - accuracy: 0.4549 - loss: 1.0428
# Epoch 25/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.4555 - loss: 1.0422
# Epoch 26/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - accuracy: 0.4555 - loss: 1.0417
# Epoch 27/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - accuracy: 0.4555 - loss: 1.0411
# Epoch 28/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - accuracy: 0.4555 - loss: 1.0406
# Epoch 29/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - accuracy: 0.4552 - loss: 1.0401
# Epoch 30/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - accuracy: 0.4555 - loss: 1.0396
# Epoch 31/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.4555 - loss: 1.0390
# Epoch 32/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - accuracy: 0.4558 - loss: 1.0384
# Epoch 33/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.4549 - loss: 1.0378
# Epoch 34/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0.4563 - loss: 1.0373
# Epoch 35/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - accuracy: 0.4558 - loss: 1.0367
# Epoch 36/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.4560 - loss: 1.0361
# Epoch 37/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - accuracy: 0.4558 - loss: 1.0355
# Epoch 38/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - accuracy: 0.4563 - loss: 1.0349
# Epoch 39/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - accuracy: 0.4563 - loss: 1.0343
# Epoch 40/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - accuracy: 0.4560 - loss: 1.0337
# Epoch 41/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - accuracy: 0.4566 - loss: 1.0331
# Epoch 42/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - accuracy: 0.4566 - loss: 1.0324
# Epoch 43/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - accuracy: 0.4563 - loss: 1.0318
# Epoch 44/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - accuracy: 0.4563 - loss: 1.0312
# Epoch 45/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - accuracy: 0.4566 - loss: 1.0305
# Epoch 46/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.4566 - loss: 1.0299
# Epoch 47/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.4560 - loss: 1.0292
# Epoch 48/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - accuracy: 0.4574 - loss: 1.0285
# Epoch 49/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - accuracy: 0.4566 - loss: 1.0278
# Epoch 50/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - accuracy: 0.4563 - loss: 1.0271
# Epoch 51/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - accuracy: 0.4571 - loss: 1.0264
# Epoch 52/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.4571 - loss: 1.0257
# Epoch 53/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - accuracy: 0.4574 - loss: 1.0250
# Epoch 54/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.4560 - loss: 1.0242
# Epoch 55/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - accuracy: 0.4577 - loss: 1.0236
# Epoch 56/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - accuracy: 0.4574 - loss: 1.0228
# Epoch 57/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.4568 - loss: 1.0221
# Epoch 58/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - accuracy: 0.4571 - loss: 1.0213
# Epoch 59/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - accuracy: 0.4571 - loss: 1.0206
# Epoch 60/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - accuracy: 0.4571 - loss: 1.0198
# Epoch 61/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.4568 - loss: 1.0190
# Epoch 62/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - accuracy: 0.4568 - loss: 1.0182
# Epoch 63/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.4571 - loss: 1.0175
# Epoch 64/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - accuracy: 0.4585 - loss: 1.0167
# Epoch 65/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - accuracy: 0.4588 - loss: 1.0159
# Epoch 66/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.4585 - loss: 1.0151
# Epoch 67/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - accuracy: 0.4582 - loss: 1.0142
# Epoch 68/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.4588 - loss: 1.0134
# Epoch 69/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - accuracy: 0.4579 - loss: 1.0125
# Epoch 70/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - accuracy: 0.4590 - loss: 1.0117
# Epoch 71/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - accuracy: 0.4579 - loss: 1.0108
# Epoch 72/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.4607 - loss: 1.0100
# Epoch 73/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.4612 - loss: 1.0092
# Epoch 74/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - accuracy: 0.4593 - loss: 1.0083
# Epoch 75/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - accuracy: 0.4601 - loss: 1.0075
# Epoch 76/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.4590 - loss: 1.0066
# Epoch 77/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.4598 - loss: 1.0058
# Epoch 78/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.4642 - loss: 1.0048
# Epoch 79/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - accuracy: 0.4604 - loss: 1.0039
# Epoch 80/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.4637 - loss: 1.0031
# Epoch 81/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.4642 - loss: 1.0022
# Epoch 82/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.4661 - loss: 1.0013
# Epoch 83/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.4650 - loss: 1.0004
# Epoch 84/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.4696 - loss: 0.9995
# Epoch 85/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.4696 - loss: 0.9986
# Epoch 86/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 0.4696 - loss: 0.9977
# Epoch 87/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.4680 - loss: 0.9968
# Epoch 88/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.4715 - loss: 0.9958
# Epoch 89/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.4694 - loss: 0.9949
# Epoch 90/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - accuracy: 0.4721 - loss: 0.9940
# Epoch 91/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.4718 - loss: 0.9931
# Epoch 92/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.4724 - loss: 0.9922
# Epoch 93/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - accuracy: 0.4751 - loss: 0.9913
# Epoch 94/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - accuracy: 0.4732 - loss: 0.9904
# Epoch 95/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - accuracy: 0.4729 - loss: 0.9894
# Epoch 96/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - accuracy: 0.4705 - loss: 0.9884
# Epoch 97/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - accuracy: 0.4819 - loss: 0.9877
# Epoch 98/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - accuracy: 0.4767 - loss: 0.9867
# Epoch 99/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - accuracy: 0.4759 - loss: 0.9859
# Epoch 100/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - accuracy: 0.4816 - loss: 0.9849
# Epoch 101/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - accuracy: 0.4830 - loss: 0.9840
# Epoch 102/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - accuracy: 0.4819 - loss: 0.9832
# Epoch 103/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.4843 - loss: 0.9822
# Epoch 104/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step - accuracy: 0.4843 - loss: 0.9814
# Epoch 105/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.4892 - loss: 0.9804
# Epoch 106/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - accuracy: 0.4860 - loss: 0.9796
# Epoch 107/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.4873 - loss: 0.9786
# Epoch 108/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - accuracy: 0.4871 - loss: 0.9778
# Epoch 109/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - accuracy: 0.4887 - loss: 0.9768
# Epoch 110/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.4922 - loss: 0.9760
# Epoch 111/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - accuracy: 0.4961 - loss: 0.9752
# Epoch 112/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - accuracy: 0.4912 - loss: 0.9743
# Epoch 113/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - accuracy: 0.4931 - loss: 0.9735
# Epoch 114/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - accuracy: 0.4958 - loss: 0.9726
# Epoch 115/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - accuracy: 0.4961 - loss: 0.9717
# Epoch 116/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - accuracy: 0.4952 - loss: 0.9710
# Epoch 117/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - accuracy: 0.4947 - loss: 0.9700
# Epoch 118/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - accuracy: 0.4982 - loss: 0.9693
# Epoch 119/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - accuracy: 0.5007 - loss: 0.9685
# Epoch 120/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - accuracy: 0.4971 - loss: 0.9677
# Epoch 121/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - accuracy: 0.5004 - loss: 0.9668
# Epoch 122/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - accuracy: 0.5020 - loss: 0.9661
# Epoch 123/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - accuracy: 0.4993 - loss: 0.9652
# Epoch 124/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - accuracy: 0.5034 - loss: 0.9645
# Epoch 125/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.5059 - loss: 0.9637
# Epoch 126/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - accuracy: 0.5059 - loss: 0.9629
# Epoch 127/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - accuracy: 0.5050 - loss: 0.9622
# Epoch 128/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.5037 - loss: 0.9614
# Epoch 129/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.5075 - loss: 0.9606
# Epoch 130/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.5059 - loss: 0.9599
# Epoch 131/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - accuracy: 0.5080 - loss: 0.9592
# Epoch 132/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 0.5105 - loss: 0.9585
# Epoch 133/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.5072 - loss: 0.9578
# Epoch 134/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.5108 - loss: 0.9571
# Epoch 135/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - accuracy: 0.5124 - loss: 0.9564
# Epoch 136/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.5105 - loss: 0.9557
# Epoch 137/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.5113 - loss: 0.9550
# Epoch 138/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - accuracy: 0.5127 - loss: 0.9543
# Epoch 139/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.5140 - loss: 0.9537
# Epoch 140/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.5108 - loss: 0.9530
# Epoch 141/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - accuracy: 0.5140 - loss: 0.9524
# Epoch 142/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - accuracy: 0.5143 - loss: 0.9517
# Epoch 143/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.5143 - loss: 0.9511
# Epoch 144/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - accuracy: 0.5157 - loss: 0.9505
# Epoch 145/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - accuracy: 0.5137 - loss: 0.9498
# Epoch 146/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.5154 - loss: 0.9493
# Epoch 147/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.5173 - loss: 0.9487
# Epoch 148/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - accuracy: 0.5195 - loss: 0.9480
# Epoch 149/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.5151 - loss: 0.9475
# Epoch 150/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - accuracy: 0.5184 - loss: 0.9469
# Epoch 151/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.5178 - loss: 0.9463
# Epoch 152/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.5189 - loss: 0.9458
# Epoch 153/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.5178 - loss: 0.9452
# Epoch 154/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.5184 - loss: 0.9447
# Epoch 155/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 0.5200 - loss: 0.9441
# Epoch 156/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.5219 - loss: 0.9435
# Epoch 157/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - accuracy: 0.5230 - loss: 0.9431
# Epoch 158/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.5214 - loss: 0.9426
# Epoch 159/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - accuracy: 0.5203 - loss: 0.9421
# Epoch 160/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - accuracy: 0.5230 - loss: 0.9415
# Epoch 161/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - accuracy: 0.5219 - loss: 0.9410
# Epoch 162/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.5208 - loss: 0.9405
# Epoch 163/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.5249 - loss: 0.9401
# Epoch 164/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - accuracy: 0.5233 - loss: 0.9396
# Epoch 165/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 0.5225 - loss: 0.9392
# Epoch 166/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - accuracy: 0.5225 - loss: 0.9387
# Epoch 167/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.5265 - loss: 0.9382
# Epoch 168/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.5230 - loss: 0.9378
# Epoch 169/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.5246 - loss: 0.9373
# Epoch 170/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.5230 - loss: 0.9369
# Epoch 171/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - accuracy: 0.5252 - loss: 0.9364
# Epoch 172/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - accuracy: 0.5246 - loss: 0.9361
# Epoch 173/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - accuracy: 0.5225 - loss: 0.9357
# Epoch 174/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - accuracy: 0.5249 - loss: 0.9353
# Epoch 175/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - accuracy: 0.5279 - loss: 0.9348
# Epoch 176/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.5263 - loss: 0.9344
# Epoch 177/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - accuracy: 0.5246 - loss: 0.9340
# Epoch 178/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.5263 - loss: 0.9336
# Epoch 179/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - accuracy: 0.5268 - loss: 0.9332
# Epoch 180/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.5276 - loss: 0.9328
# Epoch 181/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.5306 - loss: 0.9325
# Epoch 182/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.5298 - loss: 0.9321
# Epoch 183/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - accuracy: 0.5279 - loss: 0.9317
# Epoch 184/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.5295 - loss: 0.9314
# Epoch 185/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - accuracy: 0.5306 - loss: 0.9310
# Epoch 186/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.5336 - loss: 0.9307
# Epoch 187/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - accuracy: 0.5287 - loss: 0.9303
# Epoch 188/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - accuracy: 0.5323 - loss: 0.9300
# Epoch 189/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.5304 - loss: 0.9297
# Epoch 190/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.5325 - loss: 0.9293
# Epoch 191/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.5339 - loss: 0.9289
# Epoch 192/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0.5336 - loss: 0.9287
# Epoch 193/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.5304 - loss: 0.9284
# Epoch 194/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - accuracy: 0.5309 - loss: 0.9280
# Epoch 195/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.5334 - loss: 0.9277
# Epoch 196/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step - accuracy: 0.5314 - loss: 0.9274
# Epoch 197/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - accuracy: 0.5314 - loss: 0.9271
# Epoch 198/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - accuracy: 0.5336 - loss: 0.9268
# Epoch 199/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.5344 - loss: 0.9264
# Epoch 200/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - accuracy: 0.5295 - loss: 0.9262

# %% [markdown]
# Zkusíme si predikovat výstup na testovacích datech a spočítat přesnost.

# %%
# Prediction on the test data
predictions = model.predict(x_test)
predicted_classes = np.argmax(predictions, axis=-1)
model_accuracy = accuracy_score(predicted_classes, y_test)
print(model_accuracy)
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 0.5591836734693878

# %% [markdown]
# Na závěr se podíváme na matici konfuze, která nám říká, která třída byla kolikrát dobře nebo zle predikovaná.

# %%
confusion_matrix = metrics.confusion_matrix(y_test, predicted_classes)
print("Confusion matrix of our MLP:")
print(confusion_matrix)

pl.matshow(confusion_matrix)
pl.colorbar()
pl.show()

confusion_matrix = metrics.confusion_matrix(y_test, y_test)
print("How the confusion matrix looks like for the perfect classifier:")
print(confusion_matrix)

pl.matshow(confusion_matrix)
pl.colorbar()
pl.show()
# Out:
# Confusion matrix of our MLP:
# [[245 183   3]
#  [118 386  23]
#  [ 34 179  54]]
# How the confusion matrix looks like for the perfect classifier:
# [[431   0   0]
#  [  0 527   0]
#  [  0   0 267]]

# %% [markdown]
# Dataset *winequality-white.csv* je dobrou ukázkou, že ne všechna data jsou "naučitelná" nějakou takto jednoduchou sítí. Může v nich být šum, features jednotlivých dat nemusí být pro klasifikaci dostatečné, tedy potřebovali bychom v datasetu další informace, a podobně.
