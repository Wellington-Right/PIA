# %% [markdown]
# # Neuronové sítě

# %% [markdown]
# Na přednášce jste slyšeli úvod do další přírodou inspirované techniky - neuronových sítí. Mezi jejich nejjednodušší modely patří perceptron a vícevrstevný perceptron. Na cvičení si je tedy zkusíme sami naimplementovat.

# %% [markdown]
# ***Důležitá poznámka:*** Níže importujeme *sklearn*. Budete-li pipem instalovat [*"sklearn"*](https://pypi.org/project/sklearn/), dost možná se vám to v nějaké formě povede nainstalovat, pravé jméno projektu / package je ale [*"scikit-learn"*](https://pypi.org/project/scikit-learn/), a tedy by měl být instalován následovně: `pip install scikit-learn`. *sklearn* je pouze jméno pro import. Je to matoucí? Jo. Ale já to nevymyslel...

# %%
import collections
import os

# Library tqdm is a useful tool for creating progress bars
from tqdm import trange

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import pylab as pl

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn import preprocessing
from sklearn.utils import shuffle

# Turns off GPU computation of Tensorflow, when that functionality is installed
# (We are using really small networks, hence the communication overhead
# is much more significant, than the computational boost we gain by utilizing
# the power of the GPU.)
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import tensorflow as tf

# %% [markdown]
# ## Perceptron

# %% [markdown]
# Nejprve si tedy zkusíme naimplementovat jednoduchý perceptronový algoritmus učení. K tomu budeme potřebovat třídu *Perceptron*, kde si definujeme, jak jednoduchý perceptron vypadá. Při inicializaci se nastaví maximální počet iterací a learning rate, který určuje rychlost učení algoritmu, a přípraví se vektor vah a bias.
#
# Funkce *predict* nám pro daný vstup bude predikovat jeho výstup - a to tak, že se spočítá hodnota aktivační funkce ve vstupním bodě a pokud bude větší než 0, bude aktivace 1, jinak bude aktivace 0.
#
# Budeme ještě potřebovat funkci *fit*, kde se budou trénovat váhy perceptronu tak, že pro daný vstup spočteme jeho predikovaný výstup a pokud je špatný, tak upravíme váhy tak, aby příště predikoval výstup správně.

# %%
class Perceptron:
    def __init__(self, number_of_inputs, training_iterations, learning_rate=0.1):
        self.weights = np.random.normal(size=number_of_inputs)
        self.bias = np.random.normal()
        
        self.training_iterations = training_iterations
        self.learning_rate = learning_rate
        
        
    def predict(self, inputs):
        # Compute an output of the function for the given inputs, weights and bias
        intermediate_value = np.dot(inputs, self.weights) + self.bias
        # Calculate activation
        return (np.sign(intermediate_value) + 1) / 2
    
    
    def fit(self, inputs, labels):
        for _ in range(self.training_iterations):
            for x, y in zip(inputs, labels):
                prediction = self.predict(x)               
                
                # Learning
                self.weights += self.learning_rate * (y - prediction) * x
                self.bias += self.learning_rate * (y - prediction)

# %% [markdown]
# Abychom náš perceptron otestovali, vygenerujeme si náhodná data pomocí knihovny *scikit-learn*, která nám umí vrátit 2 (občas i) lineárně separabilní třídy bodů.

# %%
inputs, labels = datasets.make_blobs(centers=2, n_samples=200)

# %%
perc = Perceptron(2, 100)
perc.fit(inputs, labels)

# %% [markdown]
# Ještě by bylo fajn umět si vizualizovat výsledky - proto si napíšeme následující funkci, která bude umět vykreslit data i oddělující nadrovinu.

# %%
def draw_boundary(model, inputs, labels):
    x_min = inputs[:, 0].min() - 1
    x_max = inputs[:, 0].max() + 1
    y_min = inputs[:, 1].min() - 1 
    y_max = inputs[:, 1].max() + 1

    # Create rectangular grid with the above computed dimensions
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    
    # Drawing of the decision boundary - each point gets a color accordingly
    predicted = model.predict(np.c_[xx.ravel(), yy.ravel()])
    predicted = predicted.reshape(xx.shape)
    
    plt.figure(figsize=(12,8))
    plt.scatter(inputs[:,0], inputs[:,1], c=labels)
    plt.contourf(xx, yy, predicted, alpha=0.4)
    plt.show()

# %%
draw_boundary(perc, inputs, labels)

# %% [markdown]
# ## Vícevrstvý perceptron

# %% [markdown]
# Jednoduchý perceptron už umíme, tak si nyní s jeho pomocí zkusíme napsat vícevrstvý perceptron, neboli celou (plně propojenou) neuronovou síť. V inicializační části nastavíme velikosti vrstev a poté matice vah mezi jednotlivými vrstvami jakožto náhodné hodnoty. Dále bude třeba umět predikovat výstupní hodnotu sítě pro daný vstup. Nakonec bude potřeba funkce trénování, která pro daný vstup spočítá výstup sítě a následně updatuje váhy pomocí backpropagace.

# %%
def sigmoid(x):
    # Clip the values to prevent overflows
    x = x.clip(-5e2,5e2)
    
    return 1 / (1 + np.exp(-x))


class MultiLayerPerceptron:
    def __init__(self, layer_sizes, training_iterations=1, learning_rate=0.1):
        self.layer_sizes = layer_sizes
        self.weights = []
        self.training_iterations = training_iterations
        self.learning_rate = learning_rate
        self.last_run_activations = None
        
        for (input_layer_size, output_layer_size) in zip(self.layer_sizes, self.layer_sizes[1:]):
           self.weights.append(np.random.normal(size=(input_layer_size + 1, output_layer_size)))
           
           
    def _add_ones(self, x):
        """ Add a column of ones for bias (the first row in the weight matrix represents the biases) """
        ones = np.ones(shape=(x.shape[0], 1))
        return np.concatenate([ones, x], axis=1)
    
    
    def predict(self, inputs):
        activations = np.array(inputs)
        self.last_run_activations = [activations]
        
        try:
            for layer in self.weights:
                extended_activations = self._add_ones(activations)
                linear_combination = np.dot(extended_activations, layer)
                activations = sigmoid(linear_combination)
                self.last_run_activations.append(activations)
                
        except Exception as e:
            print("Activations:", activations)
            raise e

        return activations
    
    
    def fit(self, inputs, labels):
        progress_bar = trange(self.training_iterations)
        for i in progress_bar:
            # Compute the NN's output
            self.predict(inputs)
            
            # Perform the backpropagation
            self._perform_backpropagation(labels)
            
            # Check the performance once per hundered iterations
            if i % 100 == 0:
                predictions = self.predict(inputs)
                predicted_classes = np.argmax(predictions, axis=-1)
                model_accuracy = accuracy_score(predicted_classes, labels)
                progress_bar.set_description(f"Accuracy after iteration {i}: {model_accuracy}")
        
        
    def _perform_backpropagation(self, labels):
        # We assume a square error loss function, so L = 1/2 * sum((predictions - one_hot_targets)^2)
        one_hot_labels = np.zeros_like(self.last_run_activations[-1])
        one_hot_labels[np.arange(len(one_hot_labels)), labels] = 1
        
        # Try to implement the backpropagation yourself. - It's not easy. To be honest, it could be rather hard and maybe tricky. It is not necessary to do this,
        # so feel free to skip this one, but you can take it as a challange and check your understanding of the backpropagation
        # algorithm and of the mathematical analysis.
        # If you are willing to try, you can do so by following the ensuing steps, or do it in any other way you like.
    
        # Compute the gradients of the loss with respect to inputs of all the layers (except the first one)
        pass
    
        # Compute the gradients of the loss with respect to the model's parameters for all the layers and update the parameters
        pass

# %%
mlp = MultiLayerPerceptron([3,5,2])
# Predicting in batch
mlp.predict(np.array([[1,2,3], [1,2,7]]))
# Out:
# array([[0.01699691, 0.79837746],
#        [0.01822596, 0.80348027]])

# %% [markdown]
# ## Úkol na cvičení
#
# Zkuste si dopsat funkci `fit`, resp. `_perform_backpropagation` u vícevrstevného perceptronu a natrénovat ho na datasetu *winequality-white.csv* z UCI machine learning repository. Cílem u tohoto datasetu je predikovat kvalitu vína na základě 11 změřených fyzikálních a chemických vlastností. Kvalita se hodnotí na stupnici 0-10.

# %%
data = pd.read_csv("winequality-white.csv", delimiter=';')
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
counter=collections.Counter(data["quality"])
print(counter)
# Out:
# Counter({6: 2198, 5: 1457, 7: 880, 8: 175, 4: 163, 3: 20, 9: 5})

# %% [markdown]
# Když se ale reálně podíváme na rozložení výsledných hodnot kvality vín v datasetu, tak vidíme, že většina výstupů je mezi 5 a 7. Proto si zjednoduššíme práci a dataset si upravíme tak, aby predikoval jen 3 výstupní kategorie s hodnotami 5 až 7 tak, že 3 a 4 sloučíme s 5 a zároveň 9 a 8 sloučíme se 7.

# %%
data["quality"].replace({3: 5, 4: 5, 8: 7, 9: 7}, inplace=True)
counter=collections.Counter(data["quality"])
print(counter)
# Out:
# Counter({6: 2198, 5: 1640, 7: 1060})
# D:\Temp\ipykernel_15772\3835651965.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["quality"].replace({3: 5, 4: 5, 8: 7, 9: 7}, inplace=True)

# %% [markdown]
# Nakonec, protože klasifikace se většinou provádí do tříd *0* až *K-1*, a většina algoritmů strojového učení (včetně našich sítí) je na toto uzpůsobena, posuneme i naše labely z množiny *{5, 6, 7}* do množiny *{0, 1, 2}*.

# %%
data["quality"].replace({5: 0, 6: 1, 7: 2}, inplace=True)
# Out:
# D:\Temp\ipykernel_15772\679564709.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["quality"].replace({5: 0, 6: 1, 7: 2}, inplace=True)

# %% [markdown]
# Na tomto upraveném datasetu si nyní zkusíme pustit vícevrstevný perceptron. Vidíme, že výsledky jsou nám k ničemu, protože nemáme naprogramovanou funkci `fit`. Zkuste si ji doprogramovat.
#
# (Použijte MSE jako loss funkci, resp. její variantu bez průměrování, jen s dělením součtu čtverců dvěma, tedy *1/2 \* $\Sigma$(predictions - one_hot_targets)^2*. Jednoduše se derivuje a pro naše účely dostatečně dobře funguje. Dále derivace sigmoid funkce je následovná: *($\sigma$(x))' = $\sigma$(x) \* (1 - $\sigma$(x))* A nakonec, neděste se výsledků. Pokud jim nevěříte, zkuste svou síť na blob datasetu, na kterém dále testujeme náš tensorflow keras model, na něm by to mělo jít jedna báseň. Dataset *winequality-white.csv* je dobrou ukázkou, že ne všechna data jsou "naučitelná" nějakou takto jednoduchou sítí.  Může v nich být šum, features jednotlivých dat nemusí být pro klasifikaci dostatečné, tedy potřebovali bychom v datasetu další informace, a podobně. Vidíme to koneckonců, i když použijeme na konci tohoto notebooku tf keras síť, i ona dosáhne ve výsledku jen lehce nadpoloviční přesnosti - a to má na rozdíl od nás alespoň nějaké techniky, kterými se brání tomu skončit v lokálním optimu.)

# %%
labels = data["quality"].values
inputs = data.drop(columns="quality").values

inputs.shape
# Out:
# (4898, 11)

# %%
mlp = MultiLayerPerceptron([inputs.shape[1], 5, len(np.unique(labels))])
mlp.fit(inputs, labels)
mlp.predict(inputs)
# Out:
# Accuracy after iteration 0: 0.3156390363413638: 100%|██████████| 1/1 [00:00<00:00, 83.50it/s]
# array([[0.40777822, 0.26971605, 0.23760719],
#        [0.42379752, 0.47169863, 0.08850389],
#        [0.40777819, 0.26971618, 0.23760754],
#        ...,
#        [0.40777822, 0.26971605, 0.23760719],
#        [0.40777828, 0.26971664, 0.23760647],
#        [0.40777822, 0.26971605, 0.23760719]])

# %% [markdown]
# ## Knihovny tensorflow, keras, scikit-learn
#
# Nejprve se seznámíme s pár základními knihovnami, které budeme používat pro snažší vytváření neuronových sítí a práci s nimi. Knihovna tensorflow je symbolická matematická knihovna, která slouží pro dataflow, tedy obsahuje grafové moduly a operace, nad kterými se následně dají implementovat různé algoritmy strojového učení. Nad ní běží knihovna keras, která je navržena pro snadné experimentování s hlubokými neuronovými sítěmi. Knihovna scikit-learn zase obsahuje všechny možné běžné algoritmy strojového učení.
#
# Všechny tyto knihovny byly navrženy, aby uživateli zjednodušily práci se zpracováním dat a následné vytváření predikčních a jiných modelů, ať už pomocí neurovnových sítí nebo jiných algoritmů strojového učení.
#
# Zkusíme si tedy s pomocí těchto knihoven naimplementovat tu samou jednoduchou neuronovou sít, jakou jsme si ručně napsali výše. Budeme si potřebovat vyrobit data, potom definovat síť a nakonec ji natrénovat na trénovacích datech a nechat ji predikovat a změřit svou chybu na testovacích datech.
#
# Nejprve si vytvoříme náhodná dvojrozměrná data klasifikovatelná do n tříd, abychom si je mohli i hezky vizualizovat v grafu. K tomu bude potřeba si upravit funkci pro vizualizaci, protože vícetřídová klasifikace nám vrací výstup jakožto pole, kde pro danou jednu vybranou třídu (ideálně) bude na jejím indexu 1 a všude jinde budou 0. Tomuto výstupu se tak říká one-hot-encoding.

# %%
def draw_boundary_multiclass(model, inputs, labels):
    x_min = inputs[:, 0].min() - 1
    x_max = inputs[:, 0].max() + 1
    y_min = inputs[:, 1].min() - 1 
    y_max = inputs[:, 1].max() + 1

    # Create rectangular grid with the above computed dimensions
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    
    # Drawing of the decision boundary - each point gets a color accordingly
    predicted = model.predict(np.c_[xx.ravel(), yy.ravel()])
    
    # Extracting the predicted class number from the one-hot-encoding
    predicted = np.argmax(predicted, axis=1)
    
    predicted = predicted.reshape(xx.shape)
    
    plt.figure(figsize=(12,8))
    plt.scatter(inputs[:,0], inputs[:,1], c=labels)
    plt.contourf(xx, yy, predicted, alpha=0.4)
    plt.show()

# %% [markdown]
# Když máme upravenou funkci pro vizualizaci, vygenerujeme si náhodná data, vytvoříme model a podíváme se, jak byl model úspěšný, tedy jak dobře se natrénoval na trénovacích datech a jak umí predikovat data testovací.

# %%
# First let us prepare the data and split them to train and test sets
num_of_classes = 3
x, y = datasets.make_blobs(n_samples=300, centers=num_of_classes)

x_train, x_test = x[:250], x[250:]
y_train, y_test = y[:250], y[250:]

# %%
# Define the network architecture
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, activation=tf.nn.sigmoid)) # Inner layer with 5 neurons
model.add(tf.keras.layers.Dense(num_of_classes, activation=tf.nn.softmax)) # Output layer

# Set the optimization process hyperparameters
model.compile(optimizer="sgd", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Train the model on the training data
model.fit(x_train, y_train, epochs=200, verbose=1)
pass
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 3ms/step - loss: 1.2755 - accuracy: 0.3280
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.2107 - accuracy: 0.3280
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1540 - accuracy: 0.3280
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1039 - accuracy: 0.3280
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0601 - accuracy: 0.3280
# Epoch 6/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0225 - accuracy: 0.3280
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9909 - accuracy: 0.3280
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9641 - accuracy: 0.3280
# Epoch 9/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9414 - accuracy: 0.3280
# Epoch 10/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9220 - accuracy: 0.3280
# Epoch 11/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9058 - accuracy: 0.3280
# Epoch 12/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8912 - accuracy: 0.3680
# Epoch 13/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.8784 - accuracy: 0.4320
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8669 - accuracy: 0.5760
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8566 - accuracy: 0.6520
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8470 - accuracy: 0.7480
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8380 - accuracy: 0.8280
# Epoch 18/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.8297 - accuracy: 0.8600
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8217 - accuracy: 0.9120
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8142 - accuracy: 0.9600
# Epoch 21/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8071 - accuracy: 0.9720
# Epoch 22/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.7998 - accuracy: 0.9760
# Epoch 23/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7930 - accuracy: 0.9880
# Epoch 24/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7864 - accuracy: 0.9880
# Epoch 25/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7799 - accuracy: 0.9920
# Epoch 26/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7738 - accuracy: 0.9920
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7677 - accuracy: 0.9920
# Epoch 28/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7613 - accuracy: 0.9920
# Epoch 29/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7555 - accuracy: 0.9920
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7495 - accuracy: 0.9880
# Epoch 31/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7436 - accuracy: 0.9880
# Epoch 32/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7380 - accuracy: 0.9800
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7322 - accuracy: 0.9800
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7269 - accuracy: 0.9760
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7209 - accuracy: 0.9760
# Epoch 36/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7154 - accuracy: 0.9800
# Epoch 37/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7099 - accuracy: 0.9760
# Epoch 38/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7043 - accuracy: 0.9760
# Epoch 39/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6989 - accuracy: 0.9800
# Epoch 40/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6935 - accuracy: 0.9760
# Epoch 41/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6883 - accuracy: 0.9760
# Epoch 42/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6829 - accuracy: 0.9760
# Epoch 43/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6774 - accuracy: 0.9800
# Epoch 44/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6724 - accuracy: 0.9840
# Epoch 45/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6671 - accuracy: 0.9760
# Epoch 46/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6615 - accuracy: 0.9800
# Epoch 47/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6564 - accuracy: 0.9760
# Epoch 48/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6510 - accuracy: 0.9800
# Epoch 49/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6458 - accuracy: 0.9760
# Epoch 50/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6405 - accuracy: 0.9760
# Epoch 51/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6354 - accuracy: 0.9800
# Epoch 52/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6303 - accuracy: 0.9760
# Epoch 53/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6251 - accuracy: 0.9760
# Epoch 54/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6199 - accuracy: 0.9800
# Epoch 55/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6148 - accuracy: 0.9800
# Epoch 56/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6098 - accuracy: 0.9760
# Epoch 57/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6047 - accuracy: 0.9840
# Epoch 58/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5997 - accuracy: 0.9840
# Epoch 59/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5945 - accuracy: 0.9840
# Epoch 60/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5896 - accuracy: 0.9800
# Epoch 61/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5845 - accuracy: 0.9840
# Epoch 62/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5796 - accuracy: 0.9840
# Epoch 63/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5748 - accuracy: 0.9800
# Epoch 64/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5699 - accuracy: 0.9840
# Epoch 65/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5651 - accuracy: 0.9840
# Epoch 66/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5602 - accuracy: 0.9840
# Epoch 67/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5555 - accuracy: 0.9840
# Epoch 68/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5509 - accuracy: 0.9840
# Epoch 69/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5462 - accuracy: 0.9840
# Epoch 70/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5417 - accuracy: 0.9840
# Epoch 71/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5372 - accuracy: 0.9840
# Epoch 72/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5327 - accuracy: 0.9840
# Epoch 73/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5283 - accuracy: 0.9840
# Epoch 74/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5238 - accuracy: 0.9840
# Epoch 75/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5196 - accuracy: 0.9840
# Epoch 76/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5153 - accuracy: 0.9800
# Epoch 77/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5112 - accuracy: 0.9840
# Epoch 78/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5073 - accuracy: 0.9800
# Epoch 79/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5031 - accuracy: 0.9800
# Epoch 80/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4990 - accuracy: 0.9800
# Epoch 81/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4950 - accuracy: 0.9800
# Epoch 82/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4911 - accuracy: 0.9800
# Epoch 83/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4874 - accuracy: 0.9800
# Epoch 84/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4835 - accuracy: 0.9800
# Epoch 85/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4797 - accuracy: 0.9800
# Epoch 86/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4760 - accuracy: 0.9800
# Epoch 87/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4723 - accuracy: 0.9800
# Epoch 88/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4687 - accuracy: 0.9800
# Epoch 89/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4651 - accuracy: 0.9800
# Epoch 90/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4615 - accuracy: 0.9800
# Epoch 91/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4581 - accuracy: 0.9800
# Epoch 92/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4547 - accuracy: 0.9800
# Epoch 93/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4513 - accuracy: 0.9800
# Epoch 94/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4479 - accuracy: 0.9800
# Epoch 95/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4446 - accuracy: 0.9800
# Epoch 96/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4415 - accuracy: 0.9800
# Epoch 97/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4381 - accuracy: 0.9800
# Epoch 98/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4350 - accuracy: 0.9800
# Epoch 99/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4318 - accuracy: 0.9800
# Epoch 100/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.9800
# Epoch 101/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4255 - accuracy: 0.9800
# Epoch 102/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4226 - accuracy: 0.9800
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4194 - accuracy: 0.9800
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4165 - accuracy: 0.9800
# Epoch 105/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4135 - accuracy: 0.9800
# Epoch 106/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4106 - accuracy: 0.9840
# Epoch 107/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4077 - accuracy: 0.9800
# Epoch 108/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4051 - accuracy: 0.9800
# Epoch 109/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4021 - accuracy: 0.9800
# Epoch 110/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3992 - accuracy: 0.9840
# Epoch 111/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3965 - accuracy: 0.9840
# Epoch 112/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3939 - accuracy: 0.9840
# Epoch 113/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3910 - accuracy: 0.9800
# Epoch 114/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3886 - accuracy: 0.9840
# Epoch 115/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3858 - accuracy: 0.9800
# Epoch 116/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3831 - accuracy: 0.9800
# Epoch 117/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3805 - accuracy: 0.9840
# Epoch 118/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3780 - accuracy: 0.9840
# Epoch 119/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3754 - accuracy: 0.9840
# Epoch 120/200
# 8/8 [==============================] - 0s 874us/step - loss: 0.3730 - accuracy: 0.9840
# Epoch 121/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3705 - accuracy: 0.9840
# Epoch 122/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3680 - accuracy: 0.9840
# Epoch 123/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3656 - accuracy: 0.9840
# Epoch 124/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3633 - accuracy: 0.9840
# Epoch 125/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3608 - accuracy: 0.9840
# Epoch 126/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3585 - accuracy: 0.9840
# Epoch 127/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3562 - accuracy: 0.9840
# Epoch 128/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3539 - accuracy: 0.9840
# Epoch 129/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3516 - accuracy: 0.9840
# Epoch 130/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.9840
# Epoch 131/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3472 - accuracy: 0.9840
# Epoch 132/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3449 - accuracy: 0.9840
# Epoch 133/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3428 - accuracy: 0.9840
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3407 - accuracy: 0.9840
# Epoch 135/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3384 - accuracy: 0.9840
# Epoch 136/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3363 - accuracy: 0.9840
# Epoch 137/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3343 - accuracy: 0.9840
# Epoch 138/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3323 - accuracy: 0.9840
# Epoch 139/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3302 - accuracy: 0.9840
# Epoch 140/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3282 - accuracy: 0.9840
# Epoch 141/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3262 - accuracy: 0.9840
# Epoch 142/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3243 - accuracy: 0.9840
# Epoch 143/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3222 - accuracy: 0.9840
# Epoch 144/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3203 - accuracy: 0.9840
# Epoch 145/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3184 - accuracy: 0.9840
# Epoch 146/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3167 - accuracy: 0.9880
# Epoch 147/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3146 - accuracy: 0.9840
# Epoch 148/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3127 - accuracy: 0.9840
# Epoch 149/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3109 - accuracy: 0.9840
# Epoch 150/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3091 - accuracy: 0.9840
# Epoch 151/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3073 - accuracy: 0.9840
# Epoch 152/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3056 - accuracy: 0.9840
# Epoch 153/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3038 - accuracy: 0.9880
# Epoch 154/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3020 - accuracy: 0.9880
# Epoch 155/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3003 - accuracy: 0.9840
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2986 - accuracy: 0.9880
# Epoch 157/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2969 - accuracy: 0.9880
# Epoch 158/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2953 - accuracy: 0.9840
# Epoch 159/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2936 - accuracy: 0.9840
# Epoch 160/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2919 - accuracy: 0.9840
# Epoch 161/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2903 - accuracy: 0.9840
# Epoch 162/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2888 - accuracy: 0.9840
# Epoch 163/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2872 - accuracy: 0.9840
# Epoch 164/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2855 - accuracy: 0.9880
# Epoch 165/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2840 - accuracy: 0.9880
# Epoch 166/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2824 - accuracy: 0.9880
# Epoch 167/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2808 - accuracy: 0.9880
# Epoch 168/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2795 - accuracy: 0.9880
# Epoch 169/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2779 - accuracy: 0.9880
# Epoch 170/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2764 - accuracy: 0.9880
# Epoch 171/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2750 - accuracy: 0.9880
# Epoch 172/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2735 - accuracy: 0.9880
# Epoch 173/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2721 - accuracy: 0.9880
# Epoch 174/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2706 - accuracy: 0.9880
# Epoch 175/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2692 - accuracy: 0.9880
# Epoch 176/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2678 - accuracy: 0.9880
# Epoch 177/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2664 - accuracy: 0.9880
# Epoch 178/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2651 - accuracy: 0.9880
# Epoch 179/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2637 - accuracy: 0.9880
# Epoch 180/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2624 - accuracy: 0.9880
# Epoch 181/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2610 - accuracy: 0.9880
# Epoch 182/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2598 - accuracy: 0.9880
# Epoch 183/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2584 - accuracy: 0.9880
# Epoch 184/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2572 - accuracy: 0.9880
# Epoch 185/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2558 - accuracy: 0.9880
# Epoch 186/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2546 - accuracy: 0.9880
# Epoch 187/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2534 - accuracy: 0.9880
# Epoch 188/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2520 - accuracy: 0.9880
# Epoch 189/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2509 - accuracy: 0.9880
# Epoch 190/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2496 - accuracy: 0.9880
# Epoch 191/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2484 - accuracy: 0.9880
# Epoch 192/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2472 - accuracy: 0.9880
# Epoch 193/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2460 - accuracy: 0.9880
# Epoch 194/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2449 - accuracy: 0.9880
# Epoch 195/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2437 - accuracy: 0.9880
# Epoch 196/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2426 - accuracy: 0.9880
# Epoch 197/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2414 - accuracy: 0.9880
# Epoch 198/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2403 - accuracy: 0.9880
# Epoch 199/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2391 - accuracy: 0.9880
# Epoch 200/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2381 - accuracy: 0.9880

# %%
# We make and plot predictions on the test data
draw_boundary_multiclass(model, x_test, y_test)
# Out:
# 553/553 [==============================] - 1s 1ms/step

# %% [markdown]
# Ještě si zkusíme pustit neuronovou síť z tensorflow na nějakém reálném datasetu. Nejjednodušší volbou je dataset o víně, který jsme si už popsali výše. Nejdříve ale ještě provedeme normalizaci hodnot v datasetu tak, že všechny sloupečky budou mít hodnoty v intervalu \[0, 1\]. Normalizace se dělá proto, aby se nestalo, že některý sloupeček s hodně vysokými hodnotami bude mít příliš velký vliv na výsledný predikovaný label.

# %%
# Randomly shuffle the data
data = shuffle(data)

# Get the labels
labels = data["quality"].values

# Data normalization
values = data.drop(columns="quality").values
min_max_scaler = preprocessing.MinMaxScaler()
data_scaled = min_max_scaler.fit_transform(values)

# Split the data to train and test sets
x, y = data_scaled, labels
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
# Define the network architecture
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, activation=tf.nn.sigmoid))
model.add(tf.keras.layers.Dense(3, activation=tf.nn.softmax))

# Set the optimization process hyperparameters
model.compile(optimizer="sgd", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Train the model on the training data
model.fit(x_train, y_train, epochs=200, verbose=1)
pass
# Out:
# Epoch 1/200
# 115/115 [==============================] - 1s 2ms/step - loss: 1.1578 - accuracy: 0.3362
# Epoch 2/200
# 115/115 [==============================] - 0s 4ms/step - loss: 1.0766 - accuracy: 0.3654
# Epoch 3/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0630 - accuracy: 0.4457
# Epoch 4/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0610 - accuracy: 0.4454
# Epoch 5/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0605 - accuracy: 0.4454
# Epoch 6/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0603 - accuracy: 0.4454
# Epoch 7/200
# 115/115 [==============================] - 1s 5ms/step - loss: 1.0602 - accuracy: 0.4454
# Epoch 8/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0601 - accuracy: 0.4454
# Epoch 9/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0599 - accuracy: 0.4454
# Epoch 10/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0597 - accuracy: 0.4454
# Epoch 11/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0596 - accuracy: 0.4454
# Epoch 12/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0594 - accuracy: 0.4454
# Epoch 13/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0592 - accuracy: 0.4454
# Epoch 14/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0591 - accuracy: 0.4454
# Epoch 15/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0589 - accuracy: 0.4454
# Epoch 16/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0587 - accuracy: 0.4454
# Epoch 17/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0586 - accuracy: 0.4454
# Epoch 18/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0585 - accuracy: 0.4454
# Epoch 19/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0583 - accuracy: 0.4454
# Epoch 20/200
# 115/115 [==============================] - 0s 4ms/step - loss: 1.0582 - accuracy: 0.4454
# Epoch 21/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0579 - accuracy: 0.4454
# Epoch 22/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0578 - accuracy: 0.4454
# Epoch 23/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0576 - accuracy: 0.4454
# Epoch 24/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0575 - accuracy: 0.4454
# Epoch 25/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0573 - accuracy: 0.4454
# Epoch 26/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0571 - accuracy: 0.4454
# Epoch 27/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0570 - accuracy: 0.4454
# Epoch 28/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0568 - accuracy: 0.4454
# Epoch 29/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0566 - accuracy: 0.4454
# Epoch 30/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0564 - accuracy: 0.4454
# Epoch 31/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0563 - accuracy: 0.4454
# Epoch 32/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0561 - accuracy: 0.4454
# Epoch 33/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0559 - accuracy: 0.4454
# Epoch 34/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0557 - accuracy: 0.4454
# Epoch 35/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0556 - accuracy: 0.4454
# Epoch 36/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0554 - accuracy: 0.4454
# Epoch 37/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0552 - accuracy: 0.4454
# Epoch 38/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0550 - accuracy: 0.4454
# Epoch 39/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0548 - accuracy: 0.4454
# Epoch 40/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0546 - accuracy: 0.4454
# Epoch 41/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0544 - accuracy: 0.4454
# Epoch 42/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0542 - accuracy: 0.4454
# Epoch 43/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0540 - accuracy: 0.4454
# Epoch 44/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0538 - accuracy: 0.4454
# Epoch 45/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0536 - accuracy: 0.4454
# Epoch 46/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0534 - accuracy: 0.4454
# Epoch 47/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0532 - accuracy: 0.4454
# Epoch 48/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0530 - accuracy: 0.4454
# Epoch 49/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0528 - accuracy: 0.4454
# Epoch 50/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0525 - accuracy: 0.4454
# Epoch 51/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0523 - accuracy: 0.4454
# Epoch 52/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0520 - accuracy: 0.4454
# Epoch 53/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0517 - accuracy: 0.4454
# Epoch 54/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0516 - accuracy: 0.4454
# Epoch 55/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0513 - accuracy: 0.4454
# Epoch 56/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0510 - accuracy: 0.4454
# Epoch 57/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0508 - accuracy: 0.4454
# Epoch 58/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0506 - accuracy: 0.4454
# Epoch 59/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0503 - accuracy: 0.4454
# Epoch 60/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0500 - accuracy: 0.4454
# Epoch 61/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0497 - accuracy: 0.4454
# Epoch 62/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0495 - accuracy: 0.4454
# Epoch 63/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0492 - accuracy: 0.4454
# Epoch 64/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0489 - accuracy: 0.4454
# Epoch 65/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0486 - accuracy: 0.4454
# Epoch 66/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0483 - accuracy: 0.4454
# Epoch 67/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0480 - accuracy: 0.4454
# Epoch 68/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0477 - accuracy: 0.4454
# Epoch 69/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0474 - accuracy: 0.4454
# Epoch 70/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0471 - accuracy: 0.4454
# Epoch 71/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0467 - accuracy: 0.4454
# Epoch 72/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0464 - accuracy: 0.4454
# Epoch 73/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0461 - accuracy: 0.4454
# Epoch 74/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0458 - accuracy: 0.4454
# Epoch 75/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0454 - accuracy: 0.4454
# Epoch 76/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0450 - accuracy: 0.4454
# Epoch 77/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0446 - accuracy: 0.4454
# Epoch 78/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0443 - accuracy: 0.4454
# Epoch 79/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0439 - accuracy: 0.4454
# Epoch 80/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0435 - accuracy: 0.4454
# Epoch 81/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0432 - accuracy: 0.4454
# Epoch 82/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0427 - accuracy: 0.4454
# Epoch 83/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0423 - accuracy: 0.4454
# Epoch 84/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0420 - accuracy: 0.4454
# Epoch 85/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0415 - accuracy: 0.4454
# Epoch 86/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0411 - accuracy: 0.4454
# Epoch 87/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0406 - accuracy: 0.4454
# Epoch 88/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0402 - accuracy: 0.4454
# Epoch 89/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0398 - accuracy: 0.4454
# Epoch 90/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0393 - accuracy: 0.4454
# Epoch 91/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0389 - accuracy: 0.4454
# Epoch 92/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0384 - accuracy: 0.4454
# Epoch 93/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0379 - accuracy: 0.4454
# Epoch 94/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0374 - accuracy: 0.4454
# Epoch 95/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0370 - accuracy: 0.4454
# Epoch 96/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0365 - accuracy: 0.4454
# Epoch 97/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0359 - accuracy: 0.4457
# Epoch 98/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0354 - accuracy: 0.4457
# Epoch 99/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0349 - accuracy: 0.4454
# Epoch 100/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0344 - accuracy: 0.4462
# Epoch 101/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0338 - accuracy: 0.4460
# Epoch 102/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0333 - accuracy: 0.4454
# Epoch 103/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0327 - accuracy: 0.4462
# Epoch 104/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0322 - accuracy: 0.4462
# Epoch 105/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0316 - accuracy: 0.4462
# Epoch 106/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0310 - accuracy: 0.4462
# Epoch 107/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0304 - accuracy: 0.4462
# Epoch 108/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0298 - accuracy: 0.4462
# Epoch 109/200
# 115/115 [==============================] - 0s 3ms/step - loss: 1.0292 - accuracy: 0.4465
# Epoch 110/200
# 115/115 [==============================] - 0s 4ms/step - loss: 1.0286 - accuracy: 0.4462
# Epoch 111/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0280 - accuracy: 0.4470
# Epoch 112/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0274 - accuracy: 0.4473
# Epoch 113/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0268 - accuracy: 0.4470
# Epoch 114/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0261 - accuracy: 0.4487
# Epoch 115/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0255 - accuracy: 0.4473
# Epoch 116/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0247 - accuracy: 0.4479
# Epoch 117/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0241 - accuracy: 0.4490
# Epoch 118/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0234 - accuracy: 0.4528
# Epoch 119/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0228 - accuracy: 0.4487
# Epoch 120/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0221 - accuracy: 0.4514
# Epoch 121/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0214 - accuracy: 0.4517
# Epoch 122/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0206 - accuracy: 0.4506
# Epoch 123/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0199 - accuracy: 0.4549
# Epoch 124/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0192 - accuracy: 0.4511
# Epoch 125/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0185 - accuracy: 0.4547
# Epoch 126/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0178 - accuracy: 0.4568
# Epoch 127/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0170 - accuracy: 0.4547
# Epoch 128/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0163 - accuracy: 0.4571
# Epoch 129/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0155 - accuracy: 0.4631
# Epoch 130/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0148 - accuracy: 0.4637
# Epoch 131/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0141 - accuracy: 0.4577
# Epoch 132/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0132 - accuracy: 0.4715
# Epoch 133/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0125 - accuracy: 0.4604
# Epoch 134/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0118 - accuracy: 0.4699
# Epoch 135/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0109 - accuracy: 0.4778
# Epoch 136/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0101 - accuracy: 0.4650
# Epoch 137/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0093 - accuracy: 0.4718
# Epoch 138/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0085 - accuracy: 0.4770
# Epoch 139/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0077 - accuracy: 0.4803
# Epoch 140/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0069 - accuracy: 0.4843
# Epoch 141/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0061 - accuracy: 0.4814
# Epoch 142/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0053 - accuracy: 0.4901
# Epoch 143/200
# 115/115 [==============================] - 0s 2ms/step - loss: 1.0044 - accuracy: 0.4833
# Epoch 144/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0037 - accuracy: 0.4871
# Epoch 145/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0028 - accuracy: 0.4879
# Epoch 146/200
# 115/115 [==============================] - 0s 1ms/step - loss: 1.0020 - accuracy: 0.4936
# Epoch 147/200
# 115/115 [==============================] - 0s 4ms/step - loss: 1.0012 - accuracy: 0.4931
# Epoch 148/200
# 115/115 [==============================] - 1s 5ms/step - loss: 1.0003 - accuracy: 0.4939
# Epoch 149/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9995 - accuracy: 0.4936
# Epoch 150/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9986 - accuracy: 0.4925
# Epoch 151/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9978 - accuracy: 0.4971
# Epoch 152/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9970 - accuracy: 0.4969
# Epoch 153/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9961 - accuracy: 0.4974
# Epoch 154/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9953 - accuracy: 0.4982
# Epoch 155/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9945 - accuracy: 0.5015
# Epoch 156/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9936 - accuracy: 0.5026
# Epoch 157/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9927 - accuracy: 0.4985
# Epoch 158/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9919 - accuracy: 0.5037
# Epoch 159/200
# 115/115 [==============================] - 0s 4ms/step - loss: 0.9910 - accuracy: 0.5034
# Epoch 160/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9903 - accuracy: 0.5010
# Epoch 161/200
# 115/115 [==============================] - 0s 4ms/step - loss: 0.9894 - accuracy: 0.5053
# Epoch 162/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9886 - accuracy: 0.5015
# Epoch 163/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9877 - accuracy: 0.5034
# Epoch 164/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9869 - accuracy: 0.5039
# Epoch 165/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9861 - accuracy: 0.5056
# Epoch 166/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9852 - accuracy: 0.5059
# Epoch 167/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9844 - accuracy: 0.5132
# Epoch 168/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9836 - accuracy: 0.5050
# Epoch 169/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9827 - accuracy: 0.5091
# Epoch 170/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9819 - accuracy: 0.5146
# Epoch 171/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9811 - accuracy: 0.5072
# Epoch 172/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9803 - accuracy: 0.5203
# Epoch 173/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9795 - accuracy: 0.5113
# Epoch 174/200
# 115/115 [==============================] - 0s 4ms/step - loss: 0.9787 - accuracy: 0.5181
# Epoch 175/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9779 - accuracy: 0.5099
# Epoch 176/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9771 - accuracy: 0.5140
# Epoch 177/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9763 - accuracy: 0.5170
# Epoch 178/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9756 - accuracy: 0.5181
# Epoch 179/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9748 - accuracy: 0.5200
# Epoch 180/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9739 - accuracy: 0.5167
# Epoch 181/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9732 - accuracy: 0.5189
# Epoch 182/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9724 - accuracy: 0.5192
# Epoch 183/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9716 - accuracy: 0.5184
# Epoch 184/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9709 - accuracy: 0.5203
# Epoch 185/200
# 115/115 [==============================] - 0s 3ms/step - loss: 0.9702 - accuracy: 0.5197
# Epoch 186/200
# 115/115 [==============================] - 0s 4ms/step - loss: 0.9695 - accuracy: 0.5206
# Epoch 187/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9688 - accuracy: 0.5203
# Epoch 188/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9680 - accuracy: 0.5211
# Epoch 189/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9673 - accuracy: 0.5195
# Epoch 190/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9666 - accuracy: 0.5216
# Epoch 191/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9659 - accuracy: 0.5197
# Epoch 192/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9652 - accuracy: 0.5195
# Epoch 193/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9645 - accuracy: 0.5214
# Epoch 194/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9638 - accuracy: 0.5203
# Epoch 195/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9631 - accuracy: 0.5208
# Epoch 196/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9625 - accuracy: 0.5214
# Epoch 197/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9618 - accuracy: 0.5203
# Epoch 198/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9612 - accuracy: 0.5195
# Epoch 199/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9605 - accuracy: 0.5208
# Epoch 200/200
# 115/115 [==============================] - 0s 2ms/step - loss: 0.9598 - accuracy: 0.5176

# %% [markdown]
# Zkusíme si predikovat výstup na testovacích datech a spočítat přesnost.

# %%
# Prediction on the test data
predictions = model.predict(x_test)
predicted_classes = np.argmax(predictions, axis=-1)
model_accuracy = accuracy_score(predicted_classes, y_test)
print(model_accuracy)
# Out:
# 39/39 [==============================] - 0s 2ms/step
# 0.5338775510204081

# %% [markdown]
# Na závěr se podíváme na matici konfuze, která nám říká, která třída byla kolikrát dobře nebo zle predikovaná.

# %%
confusion_matrix = metrics.confusion_matrix(y_test, predicted_classes)
print("Confusion matrix of our MLP:")
print(confusion_matrix)

pl.matshow(confusion_matrix)
pl.colorbar()
pl.show()

confusion_matrix = metrics.confusion_matrix(y_test, y_test)
print("How the confusion matrix looks like for the perfect classifier:")
print(confusion_matrix)

pl.matshow(confusion_matrix)
pl.colorbar()
pl.show()
# Out:
# Confusion matrix of our MLP:
# [[207 198   0]
#  [115 447   0]
#  [ 19 239   0]]
# How the confusion matrix looks like for the perfect classifier:
# [[405   0   0]
#  [  0 562   0]
#  [  0   0 258]]
