# %% [markdown]
# # Neuronové sítě

# %% [markdown]
# Na přednášce jste slyšeli úvod do další přírodou inspirované techniky - neuronových sítí. Mezi jejich nejjednodušší modely patří perceptron a vícevrstevný perceptron. Na cvičení si je tedy zkusíme sami naimplementovat.

# %%
import collections
import os

# Library tqdm is a useful tool for creating progress bars
from tqdm import trange

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import pylab as pl

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn import preprocessing
from sklearn.utils import shuffle

# Turns off GPU computation of Tensorflow, when that functionality is installed
# (We are using really small networks, hence the communication overhead
# is much more significant, than the computational boost we gain by utilizing
# the power of the GPU.)
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import tensorflow as tf

# %% [markdown]
# ## Perceptron

# %% [markdown]
# Nejprve si tedy zkusíme naimplementovat jednoduchý perceptronový algoritmus učení. K tomu budeme potřebovat třídu *Perceptron*, kde si definujeme, jak jednoduchý perceptron vypadá. Při inicializaci se nastaví maximální počet iterací a learning rate, který určuje rychlost učení algoritmu, a přípraví se vektor vah a bias.
#
# Funkce *predict* nám pro daný vstup bude predikovat jeho výstup - a to tak, že se spočítá hodnota aktivační funkce ve vstupním bodě a pokud bude větší než 0, bude aktivace 1, jinak bude aktivace 0.
#
# Budeme ještě potřebovat funkci *fit*, kde se budou trénovat váhy perceptronu tak, že pro daný vstup spočteme jeho predikovaný výstup a pokud je špatný, tak upravíme váhy tak, aby příště predikoval výstup správně.

# %%
class Perceptron:
    def __init__(self, number_of_inputs, training_iterations, learning_rate=0.1):
        self.weights = np.random.normal(size=number_of_inputs)
        self.bias = np.random.normal()
        
        self.training_iterations = training_iterations
        self.learning_rate = learning_rate
        
        
    def predict(self, inputs):
        # Compute an output of the function for the given inputs, weights and bias
        intermediate_value = np.dot(inputs, self.weights) + self.bias
        # Calculate activation
        return (np.sign(intermediate_value) + 1) / 2
    
    
    def fit(self, inputs, labels):
        for _ in range(self.training_iterations):
            for x, y in zip(inputs, labels):
                prediction = self.predict(x)               
                
                # Learning
                self.weights += self.learning_rate * (y - prediction) * x
                self.bias += self.learning_rate * (y - prediction)

# %% [markdown]
# Abychom náš perceptron otestovali, vygenerujeme si náhodná data pomocí knihovny *scikit-learn*, která nám umí vrátit 2 (občas i) lineárně separabilní třídy bodů.

# %%
inputs, labels = datasets.make_blobs(centers=2, n_samples=200)

# %%
perc = Perceptron(2, 100)
perc.fit(inputs, labels)

# %% [markdown]
# Ještě by bylo fajn umět si vizualizovat výsledky - proto si napíšeme následující funkci, která bude umět vykreslit data i oddělující nadrovinu.

# %%
def draw_boundary(model, inputs, labels):
    x_min = inputs[:, 0].min() - 1
    x_max = inputs[:, 0].max() + 1
    y_min = inputs[:, 1].min() - 1 
    y_max = inputs[:, 1].max() + 1

    # Create rectangular grid with the above computed dimensions
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    
    # Drawing of the decision boundary - each point gets a color accordingly
    predicted = model.predict(np.c_[xx.ravel(), yy.ravel()])
    predicted = predicted.reshape(xx.shape)
    
    plt.figure(figsize=(12,8))
    plt.scatter(inputs[:,0], inputs[:,1], c=labels)
    plt.contourf(xx, yy, predicted, alpha=0.4)
    plt.show()

# %%
draw_boundary(perc, inputs, labels)

# %% [markdown]
# ## Vícevrstvý perceptron

# %% [markdown]
# Jednoduchý perceptron už umíme, tak si nyní s jeho pomocí zkusíme napsat vícevrstvý perceptron, neboli celou (plně propojenou) neuronovou síť.
#
# Nejprve ale budeme potřebovat aktivační funkce (sigmoid a tanh) a rovnou si napíšeme i pomocnou funkci na získání přesnosti modelu na daných datech.
#
# Pro samotný MLP nastavíme v inicializační části velikosti vrstev a poté matice vah mezi jednotlivými vrstvami jakožto náhodné hodnoty. Dále bude třeba umět predikovat výstupní hodnotu sítě pro daný vstup. Nakonec bude potřeba funkce trénování, která pro daný vstup spočítá výstup sítě a následně updatuje váhy pomocí backpropagace. K tomu budeme potřebovat derivace našich aktivačních funkcí (viz níže). Zároveň budeme potřebovat loss funkci. Použijeme MSE (Mean Square Error), resp. její variantu bez průměrování, jen s dělením součtu čtverců dvěma, tedy $\frac{1}{2} \sum(\texttt{predictions} - \texttt{one\_hot\_targets})^2$. Jednoduše se derivuje a pro naše účely funguje dostatečně.
#
# Derivace sigmoid funkce je následující: $(\sigma(x))' = \sigma(x) \cdot (1 - \sigma(x))$
#
# Derivace funkce tanh pak: $(\tanh(x))' = 1 - \tanh(x)^2$

# %%
def get_model_accuracy(model, inputs, labels):
    predictions = model.predict(inputs)
    predicted_classes = np.argmax(predictions, axis=-1)
    model_accuracy = accuracy_score(predicted_classes, labels)
    
    return model_accuracy


def sigmoid(x):
    # Clip the values to prevent overflows
    x = x.clip(-5e2,5e2)
    
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return np.tanh(x)


class MultiLayerPerceptron:
    def __init__(self, layer_sizes, training_iterations=int(1e3), learning_rate=1e-2):
        self.layer_sizes = layer_sizes
        self.weight_matrices = [] # The weight matrices include biases
        self.training_iterations = training_iterations
        self.learning_rate = learning_rate
        self.last_run_activations = None
        
        for (input_layer_size, output_layer_size) in zip(self.layer_sizes, self.layer_sizes[1:]):
           self.weight_matrices.append(np.random.normal(size=(input_layer_size + 1, output_layer_size)))
           
           
    def _add_ones(self, x):
        """ Add a column of ones for bias (the first row in the weight matrix represents the biases) """
        ones = np.ones(shape=(x.shape[0], 1))
        return np.concatenate([ones, x], axis=1)
    
    
    def predict(self, inputs):
        # We assume that the input is a batch of samples, and the computation is performed for the whole batch at once
        
        activations = np.array(inputs)
        self.last_run_activations = [activations]
        
        for i, weight_matrix in enumerate(self.weight_matrices):
            extended_activations = self._add_ones(activations)
            linear_combination = np.dot(extended_activations, weight_matrix)
            
            if i < len(self.weight_matrices) - 1:
                activations = tanh(linear_combination) # Hidden layers (tanh activation)
            else:
                activations = sigmoid(linear_combination) # Output layer (sigmoid activation)
            
            self.last_run_activations.append(activations)
        
        return activations
    
    
    def fit(self, inputs, labels):
        progress_bar = trange(self.training_iterations)
        for i in progress_bar:
            # Compute the NN's output
            self.predict(inputs)
            
            # Perform the backpropagation
            self._perform_backpropagation(labels)
            
            # Check the performance once per hundered iterations
            if (i+1) % 100 == 0:
                model_accuracy = get_model_accuracy(self, inputs, labels)
                progress_bar.set_description(f"Training accuracy after iteration {i+1}: {model_accuracy}")
    
    
    def _perform_backpropagation(self, labels):
        # The first dimension of labels, layer activations and gradients is the batch size, which we will sum over in the end
        
        # We assume a square error loss function, so L = 1/2 * sum((predictions - one_hot_targets)^2)
        one_hot_labels = np.zeros_like(self.last_run_activations[-1])
        one_hot_labels[np.arange(len(one_hot_labels)), labels] = 1
        
        
        # Compute the gradients of the loss with respect to inputs of all the layers (except the first one),
        # more specifically, with respect to the linear combinations inside each layer
        dLoss_wrt_Layer_activation_inputs = list()
        
        ## Output layer
        dLoss_wrt_Output_layer_activation_output = \
            self.last_run_activations[-1] - one_hot_labels
            
        # Derivative of the output layer activation function, which is sigmoid
        dOutput_layer_activation_output_wrt_Output_layer_activation_input = \
            self.last_run_activations[-1] * (1 - self.last_run_activations[-1])
        
        dLoss_wrt_Output_layer_activation_input = \
            dLoss_wrt_Output_layer_activation_output * dOutput_layer_activation_output_wrt_Output_layer_activation_input
        
        dLoss_wrt_Layer_activation_inputs.append(dLoss_wrt_Output_layer_activation_input)
        
        ## Hidden layers
        for i in range(len(self.last_run_activations)-2, 0, -1):
            # Derivative of the loss with respect to the following layer's activation input (the result of the following layer's linear combination)
            dLoss_wrt_Following_layer_activation_input = dLoss_wrt_Layer_activation_inputs[-1]
            
            # Derivative of the loss with respect to the current layer activation's output (input to the linear combination of the following layer)
            dLoss_wrt_Current_layer_activation_output = \
                np.dot(dLoss_wrt_Following_layer_activation_input, self.weight_matrices[i][1:,:].T) # The first row of the weight matrix is for bias, so we skip it
            
            # Derivative of the current (hidden) layer activation function, which is tanh
            dCurrent_layer_activation_output_wrt_Current_layer_activation_input = \
                1 - self.last_run_activations[i] ** 2
            
            dLoss_wrt_Current_layer_activation_input = \
                dLoss_wrt_Current_layer_activation_output * dCurrent_layer_activation_output_wrt_Current_layer_activation_input
                
            dLoss_wrt_Layer_activation_inputs.append(dLoss_wrt_Current_layer_activation_input)
                
        dLoss_wrt_Layer_activation_inputs = reversed(dLoss_wrt_Layer_activation_inputs)
        
        
        # Compute the gradients of the loss with respect to the model's parameters for all the layers and update the parameters
        for i, (dLoss_wrt_Current_layer_activation_input, inputs_of_the_current_layer) in enumerate(zip(dLoss_wrt_Layer_activation_inputs, self.last_run_activations)):            

            # Compute derivative with respect to bias
            dLoss_wrt_Current_bias = np.sum(dLoss_wrt_Current_layer_activation_input, axis=0, keepdims=True)
            
            # Compute derivative with respect to weights
            # (Axes in the extended arrays for the current layer are as follows: [batch_size, number_of_input_features, number_of_output_features])
            dLoss_wrt_Current_weights = \
                np.sum(dLoss_wrt_Current_layer_activation_input[:,np.newaxis,:] * inputs_of_the_current_layer[:,:,np.newaxis], axis=0)
            
            # Concatenate the two derivatives into gradient and use that to update the parameters
            gradient = np.concatenate([dLoss_wrt_Current_bias, dLoss_wrt_Current_weights], axis=0)
            self.weight_matrices[i] -= self.learning_rate * gradient

# %%
mlp = MultiLayerPerceptron([3,5,2]) # MLP with 3 input features, 5 hidden neurons and 2 output neurons

# Predicting in batch
mlp.predict(np.array([[1,2,3], [1,2,7]]))
# Out:
# array([[0.16552418, 0.21916843],
#        [0.10354311, 0.12413681]])

# %% [markdown]
# Zkusme si tedy teď naši neuronovou síť natrénovat na nějakých datech.

# %% [markdown]
# Nejprve si vytvoříme náhodná dvojrozměrná data klasifikovatelná do n tříd, abychom si je mohli i hezky vizualizovat v grafu. K tomu bude potřeba si upravit funkci pro vizualizaci, protože vícetřídová klasifikace nám vrací výstup jakožto pole, kde pro danou jednu vybranou třídu (ideálně) bude na jejím indexu 1 a všude jinde budou 0. Tomuto výstupu se tak říká one-hot-encoding.

# %%
def draw_boundary_multiclass(model, inputs, labels):
    x_min = inputs[:, 0].min() - 1
    x_max = inputs[:, 0].max() + 1
    y_min = inputs[:, 1].min() - 1 
    y_max = inputs[:, 1].max() + 1

    # Create rectangular grid with the above computed dimensions
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    
    # Drawing of the decision boundary - each point gets a color accordingly
    predicted = model.predict(np.c_[xx.ravel(), yy.ravel()])
    
    # Extracting the predicted class number from the one-hot-encoding
    predicted = np.argmax(predicted, axis=1)
    
    predicted = predicted.reshape(xx.shape)
    
    plt.figure(figsize=(12,8))
    plt.scatter(inputs[:,0], inputs[:,1], c=labels)
    plt.contourf(xx, yy, predicted, alpha=0.4)
    plt.show()

# %% [markdown]
# Když máme upravenou funkci pro vizualizaci, vygenerujeme si náhodná data, vytvoříme model a podíváme se, jak byl model úspěšný, tedy jak dobře se natrénoval na trénovacích datech a jak umí predikovat data testovací.

# %%
# First let us prepare the data and split them to train and test sets
num_of_classes = 3
x, y = datasets.make_blobs(n_samples=300, centers=num_of_classes)

x_train, x_test = x[:250], x[250:]
y_train, y_test = y[:250], y[250:]

# %%
mlp = MultiLayerPerceptron([x_train.shape[1], 5, num_of_classes], training_iterations=1_000)
mlp.fit(x_train, y_train)

test_predictions = mlp.predict(x_test)
predicted_classes = np.argmax(test_predictions, axis=-1)
model_accuracy = accuracy_score(predicted_classes, y_test)
print("Accuracy on test data:", model_accuracy)
# Out:
# Training accuracy after iteration 1000: 1.0: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 5248.11it/s]
# Accuracy on test data: 1.0

# %%
# We make and plot predictions on the test data
draw_boundary_multiclass(mlp, x_test, y_test)

# %% [markdown]
# ## Knihovny tensorflow, keras, scikit-learn
#
# Nejprve se seznámíme s pár základními knihovnami, které budeme používat pro snažší vytváření neuronových sítí a práci s nimi. Knihovna tensorflow je symbolická matematická knihovna, která slouží pro dataflow, tedy obsahuje grafové moduly a operace, nad kterými se následně dají implementovat různé algoritmy strojového učení. Nad ní běží knihovna keras, která je navržena pro snadné experimentování s hlubokými neuronovými sítěmi. Knihovna scikit-learn zase obsahuje všechny možné běžné algoritmy strojového učení.
#
# Všechny tyto knihovny byly navrženy, aby uživateli zjednodušily práci se zpracováním dat a následné vytváření predikčních a jiných modelů, ať už pomocí neurovnových sítí nebo jiných algoritmů strojového učení.
#
# Zkusíme si tedy s pomocí těchto knihoven naimplementovat tu samou jednoduchou neuronovou sít, jakou jsme si ručně napsali výše. Budeme si potřebovat  definovat síť, natrénovat ji na trénovacích datech a nakonec ji nechat predikovat na testovacích datech.
#
# Oproti našemu MLP, kde jsme museli vš derivovat sami, zde to knihovna udělá za nás. Můžeme si tedy dovolit využít pro multinomiální klasifikační úlohu lepší loss funkci a aktivaci na výstupu - kategorickou cross-entropy loss a softmax funkci.

# %%
# Define the network architecture
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, activation=tf.nn.tanh)) # Inner layer with 5 neurons
model.add(tf.keras.layers.Dense(num_of_classes, activation=tf.nn.softmax)) # Output layer

# Set the optimization process hyperparameters
model.compile(optimizer="sgd", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0428
# Epoch 135/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0425
# Epoch 136/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0422
# Epoch 137/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0419
# Epoch 138/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0416
# Epoch 139/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0414
# Epoch 140/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0411
# Epoch 141/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0408
# Epoch 142/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0406
# Epoch 143/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0403
# Epoch 144/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0400
# Epoch 145/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0398
# Epoch 146/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0395
# Epoch 147/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0393
# Epoch 148/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0390
# Epoch 149/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0388
# Epoch 150/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0386
# Epoch 151/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0383
# Epoch 152/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0381
# Epoch 153/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0379
# Epoch 154/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0376
# Epoch 155/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0374
# Epoch 156/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0372
# Epoch 157/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0370
# Epoch 158/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0368
# Epoch 159/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0366
# Epoch 160/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0363
# Epoch 161/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0361
# Epoch 162/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0359
# Epoch 163/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0357
# Epoch 164/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0355
# Epoch 165/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0353
# Epoch 166/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0351
# Epoch 167/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0349
# Epoch 168/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0347
# Epoch 169/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0345
# Epoch 170/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0344
# Epoch 171/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0342
# Epoch 172/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0340
# Epoch 173/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0338
# Epoch 174/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0336
# Epoch 175/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0334
# Epoch 176/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0333
# Epoch 177/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0331
# Epoch 178/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0329
# Epoch 179/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0327
# Epoch 180/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0326
# Epoch 181/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0324
# Epoch 182/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0322
# Epoch 183/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0321
# Epoch 184/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0319
# Epoch 185/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0318
# Epoch 186/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0316
# Epoch 187/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0314
# Epoch 188/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0313
# Epoch 189/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0311
# Epoch 190/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0310
# Epoch 191/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0308
# Epoch 192/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0307
# Epoch 193/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0305
# Epoch 194/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0304
# Epoch 195/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0302
# Epoch 196/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0301
# Epoch 197/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0299
# Epoch 198/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0298
# Epoch 199/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0297
# Epoch 200/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0295

# %%
# We make and plot predictions on the test data
draw_boundary_multiclass(model, x_test, y_test)
# Out:
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# Ještě si zkusíme pustit neuronovou síť z tensorflow na nějakém reálném datasetu. Použijeme dataset *winequality-white.csv* z UCI machine learning repository. Cílem u tohoto datasetu je predikovat kvalitu vína na základě 11 změřených fyzikálních a chemických vlastností. Kvalita se hodnotí na stupnici 0-10. Pojďme si nejdříve tento dataset představit a upravit.

# %%
data = pd.read_csv("winequality-white.csv", delimiter=';')
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
counter = collections.Counter(data["quality"])
print(counter)
# Out:
# Counter({6: 2198, 5: 1457, 7: 880, 8: 175, 4: 163, 3: 20, 9: 5})

# %% [markdown]
# Když se ale reálně podíváme na rozložení výsledných hodnot kvality vín v datasetu, tak vidíme, že většina výstupů je mezi 5 a 7. Proto si zjednoduššíme práci a dataset si upravíme tak, aby predikoval jen 3 výstupní kategorie s hodnotami 5 až 7 tak, že 3 a 4 sloučíme s 5 a zároveň 9 a 8 sloučíme se 7.

# %%
data["quality"] = data["quality"].replace({3: 5, 4: 5, 8: 7, 9: 7})
counter = collections.Counter(data["quality"])
print(counter)
# Out:
# Counter({6: 2198, 5: 1640, 7: 1060})

# %% [markdown]
# Nakonec, protože klasifikace se většinou provádí do tříd *0* až *K-1*, a většina algoritmů strojového učení (včetně našich sítí) je na toto uzpůsobena, posuneme i naše labely z množiny *{5, 6, 7}* do množiny *{0, 1, 2}*.

# %%
data["quality"] = data["quality"].replace({5: 0, 6: 1, 7: 2})

# %% [markdown]
# Máme tedy již upravené výstupy. Pojďme se teď podívat na vstupy a připravme si data již finálně pro naši síť.
#
# Provedeme přeškálování hodnot v datasetu tak, že všechny sloupečky budou mít hodnoty v intervalu \[0, 1\]. Škálování se dělá proto, aby se nestalo, že některý sloupeček s hodně vysokými hodnotami bude mít příliš velký vliv na výsledný predikovaný label.

# %%
# Randomly shuffle the data
data = shuffle(data)

# Get the labels
labels = data["quality"].values

# Data normalization
values = data.drop(columns="quality").values
min_max_scaler = preprocessing.MinMaxScaler()
data_scaled = min_max_scaler.fit_transform(values)

# Split the data to train and test sets
x, y = data_scaled, labels
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %% [markdown]
# Nakonec už nám nezbývá nic jiného, než si definovat naši síť a natrénovat ji.

# %%
# Define the network architecture
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, activation=tf.nn.sigmoid))
model.add(tf.keras.layers.Dense(3, activation=tf.nn.softmax))

# Set the optimization process hyperparameters
model.compile(optimizer="sgd", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Train the model on the training data
model.fit(x_train, y_train, epochs=200, verbose=1)
pass
# Out:
# Epoch 1/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3324 - loss: 1.1873
# Epoch 2/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3692 - loss: 1.0803
# Epoch 3/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0607
# Epoch 4/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0572
# Epoch 5/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0565
# Epoch 6/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0561
# Epoch 7/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0558
# Epoch 8/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0555
# Epoch 9/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0553
# Epoch 10/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0550
# Epoch 11/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0547
# Epoch 12/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0545
# Epoch 13/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0542
# Epoch 14/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0539
# Epoch 15/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0536
# Epoch 16/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0534
# Epoch 17/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0531
# Epoch 18/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0528
# Epoch 19/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0525
# Epoch 20/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0523
# Epoch 21/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0520
# Epoch 22/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0517
# Epoch 23/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0515
# Epoch 24/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0511
# Epoch 25/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0508
# Epoch 26/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0505
# Epoch 27/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0502
# Epoch 28/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0500
# Epoch 29/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0496
# Epoch 30/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0493
# Epoch 31/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0490
# Epoch 32/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0487
# Epoch 33/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0484
# Epoch 34/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0480
# Epoch 35/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0477
# Epoch 36/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0473
# Epoch 37/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0470
# Epoch 38/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0466
# Epoch 39/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0463
# Epoch 40/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0459
# Epoch 41/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0455
# Epoch 42/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0451
# Epoch 43/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0447
# Epoch 44/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0443
# Epoch 45/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0439
# Epoch 46/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0435
# Epoch 47/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0431
# Epoch 48/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0427
# Epoch 49/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0423
# Epoch 50/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0418
# Epoch 51/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0413
# Epoch 52/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0408
# Epoch 53/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0404
# Epoch 54/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0399
# Epoch 55/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0394
# Epoch 56/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0389
# Epoch 57/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0384
# Epoch 58/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0379
# Epoch 59/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0374
# Epoch 60/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4517 - loss: 1.0368
# Epoch 61/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0363
# Epoch 62/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0357
# Epoch 63/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0351
# Epoch 64/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0345
# Epoch 65/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0339
# Epoch 66/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0333
# Epoch 67/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0328
# Epoch 68/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0321
# Epoch 69/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0315
# Epoch 70/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4517 - loss: 1.0308
# Epoch 71/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0302
# Epoch 72/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0295
# Epoch 73/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0288
# Epoch 74/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0282
# Epoch 75/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0274
# Epoch 76/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0267
# Epoch 77/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0260
# Epoch 78/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0252
# Epoch 79/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0245
# Epoch 80/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0237
# Epoch 81/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0229
# Epoch 82/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4517 - loss: 1.0221
# Epoch 83/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0214
# Epoch 84/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.0205
# Epoch 85/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0198
# Epoch 86/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 1.0189
# Epoch 87/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0181
# Epoch 88/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0172
# Epoch 89/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.0164
# Epoch 90/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4519 - loss: 1.
200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5135 - loss: 0.9489
# Epoch 164/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5173 - loss: 0.9482
# Epoch 165/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5157 - loss: 0.9475
# Epoch 166/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5189 - loss: 0.9469
# Epoch 167/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5178 - loss: 0.9462
# Epoch 168/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5206 - loss: 0.9456
# Epoch 169/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5132 - loss: 0.9449
# Epoch 170/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5238 - loss: 0.9443
# Epoch 171/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5211 - loss: 0.9436
# Epoch 172/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5189 - loss: 0.9431
# Epoch 173/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5227 - loss: 0.9425
# Epoch 174/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5219 - loss: 0.9419
# Epoch 175/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5219 - loss: 0.9413
# Epoch 176/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5233 - loss: 0.9407
# Epoch 177/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5257 - loss: 0.9402
# Epoch 178/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5255 - loss: 0.9396
# Epoch 179/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5233 - loss: 0.9390
# Epoch 180/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5279 - loss: 0.9386
# Epoch 181/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5252 - loss: 0.9380
# Epoch 182/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5276 - loss: 0.9375
# Epoch 183/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5268 - loss: 0.9370
# Epoch 184/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5287 - loss: 0.9364
# Epoch 185/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5290 - loss: 0.9360
# Epoch 186/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5293 - loss: 0.9355
# Epoch 187/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5293 - loss: 0.9350
# Epoch 188/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5285 - loss: 0.9345
# Epoch 189/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5290 - loss: 0.9341
# Epoch 190/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5301 - loss: 0.9336
# Epoch 191/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5285 - loss: 0.9331
# Epoch 192/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5276 - loss: 0.9327
# Epoch 193/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5304 - loss: 0.9323
# Epoch 194/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5287 - loss: 0.9319
# Epoch 195/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5282 - loss: 0.9314
# Epoch 196/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5295 - loss: 0.9310
# Epoch 197/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5298 - loss: 0.9306
# Epoch 198/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5306 - loss: 0.9302
# Epoch 199/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5306 - loss: 0.9298
# Epoch 200/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5306 - loss: 0.9294

# %% [markdown]
# Zkusíme si predikovat výstup na testovacích datech a spočítat přesnost.

# %%
# Prediction on the test data
predictions = model.predict(x_test)
predicted_classes = np.argmax(predictions, axis=-1)
model_accuracy = accuracy_score(predicted_classes, y_test)
print(model_accuracy)
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 0.5248979591836734

# %% [markdown]
# Na závěr se podíváme na matici konfuze, která nám říká, která třída byla kolikrát dobře nebo zle predikovaná.

# %%
confusion_matrix = metrics.confusion_matrix(y_test, predicted_classes)
print("Confusion matrix of our MLP:")
print(confusion_matrix)

pl.matshow(confusion_matrix)
pl.colorbar()
pl.show()

confusion_matrix = metrics.confusion_matrix(y_test, y_test)
print("How the confusion matrix looks like for the perfect classifier:")
print(confusion_matrix)

pl.matshow(confusion_matrix)
pl.colorbar()
pl.show()
# Out:
# Confusion matrix of our MLP:
# [[225 194   0]
#  [129 397  12]
#  [ 30 217  21]]
# How the confusion matrix looks like for the perfect classifier:
# [[419   0   0]
#  [  0 538   0]
#  [  0   0 268]]

# %% [markdown]
# Dataset *winequality-white.csv* je dobrou ukázkou, že ne všechna data jsou naučitelná nějakou takto jednoduchou sítí. Buď je problém v našem modelu (myšleno potřebovali bychom "expresivnější", tedy složitější, lepší model), nebo může být problém v datech samotných: Může v nich být šum, features jednotlivých dat nemusí být pro klasifikaci dostatečné, tedy potřebovali bychom v datasetu další informace, a podobně.

# %% [markdown]
# ## Úkol na cvičení
#
# Dnes není žádná úloha vysloveně k vypracování. Zkuste si ale pořádně projít princip i naši implementaci backpropagace a zkuste pochopit, co se vlastně přesně děje, jak přesně že to tedy funguje.
